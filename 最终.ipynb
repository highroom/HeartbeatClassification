# %%
import os
import gc
import math

import pandas as pd
import numpy as np

import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDRegressor, LinearRegression, Ridge
from sklearn.preprocessing import MinMaxScaler


from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import log_loss, make_scorer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score

from tqdm import tqdm
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2 
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2 
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('testA.csv')
train.head()
# Out:
#    id                                  heartbeat_signals  label
# 0   0  0.9912297987616655,0.9435330436439665,0.764677...    0.0
# 1   1  0.9714822034884503,0.9289687459588268,0.572932...    0.0
# 2   2  1.0,0.9591487564065292,0.7013782792997189,0.23...    2.0
# 3   3  0.9757952826275774,0.9340884687738161,0.659636...    0.0
# 4   4  0.0,0.055816398940721094,0.26129357194994196,0...    2.0

# %%
train = train.join(train['heartbeat_signals'].str.split(',').apply(pd.Series).astype('float'))
train.drop(columns='heartbeat_signals', inplace=True)
train = train.rename({i:f's_{i}' for i in range(205)}, axis=1)

test = test.join(test['heartbeat_signals'].str.split(',').apply(pd.Series).astype('float'))
test.drop(columns='heartbeat_signals', inplace=True)
test = test.rename({i:f's_{i}' for i in range(205)}, axis=1)

# %%
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 157.93 MB
# Memory usage after optimization is: 39.67 MB
# Decreased by 74.9%
# Memory usage of dataframe is 31.43 MB
# Memory usage after optimization is: 7.90 MB
# Decreased by 74.9%

# %%
X_train = train.drop(columns=['id', 'label'])
y_train = train['label']
X_test = test.drop(columns='id')

# %%
seed = 23
params = {
                'boosting_type': 'gbdt',
                'objective': 'multiclass',
                'num_class': 4,
                'num_leaves': 2 ** 5,
                'feature_fraction': 0.8,
                'bagging_fraction': 0.8,
                'bagging_freq': 4,
                'learning_rate': 0.1,
                'seed': seed,
                'nthread': 28,
                'n_jobs':24,
                'verbose': -1,
            }

# %%
param_grid = {
        'num_leaves':(10, 200),
        'max_depth':(3, 20),
        'bagging_fraction':(0.5, 1.0),
        'feature_fraction':(0.5, 1.0),
        'bagging_freq':(0, 100),
        'min_data_in_leaf':(10,100),
        'min_child_weight':(0, 10),
        'min_split_gain':(0.0, 1.0),
        'reg_alpha':(0.0, 10),
        'reg_lambda':(0.0, 10),
    }

# %%
"""通过网格搜索确定最优参数"""
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import f1_score

# 设置5折交叉验证
cv_fold = KFold(n_splits=5, shuffle=True, random_state=2021)

model_lgb = lgb.LGBMClassifier(**params)

f1 = make_scorer(f1_score, average='micro')
grid_search = RandomizedSearchCV(estimator=model_lgb, param_distributions=param_grid, cv=cv_fold, scoring=f1)
grid_search.fit(X_train, y_train)

# %%
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# LGBMClassifier(bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.5,
#                max_depth=20, min_child_weight=10, min_data_in_leaf=10,
#                n_jobs=24, nthread=28, num_class=4, num_leaves=200,
#                objective='multiclass', reg_alpha=10, reg_lambda=10, seed=23,
#                verbose=-1)
# {'reg_lambda': 10, 'reg_alpha': 10, 'num_leaves': 200, 'min_split_gain': 0.0, 'min_data_in_leaf': 10, 'min_child_weight': 10, 'max_depth': 20, 'feature_fraction': 0.5, 'bagging_freq': 0, 'bagging_fraction': 1.0}
# 0.9808399999999999

# %%
random_results = pd.DataFrame(grid_search.cv_results_).drop(columns='params').sort_values('mean_test_score', ascending=False)
random_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       6.814429      0.391619         0.257170        0.005180
# 0       5.259064      0.034182         0.190890        0.001850
# 8       3.898224      0.175918         0.186580        0.006944
# 5       5.243801      0.086056         0.176331        0.000808
# 6       3.846641      0.077165         0.158775        0.014486
# 1       2.968158      0.065490         0.151794        0.004059
# 3       3.894835      0.065135         0.152591        0.003278
# 2       3.928005      0.146244         0.150397        0.005863
# 4       3.966175      0.095525         0.153589        0.003732
# 7       3.860762      0.107416         0.147906        0.005996
#
#   param_reg_lambda param_reg_alpha param_num_leaves param_min_split_gain  \
# 9               10              10              200                    0
# 0                0               0              200                    1
# 8                0              10               10                    1
# 5               10               0               10                    0
# 6                0               0              200                    1
# 1               10              10              200                    0
# 3                0              10               10                    1
# 2                0              10               10                    0
# 4                0              10              200                    0
# 7                0              10               10                    0
#
#   param_min_data_in_leaf param_min_child_weight  ... param_bagging_freq  \
# 9                     10                     10  ...                  0
# 0                    100                      0  ...                100
# 8                    100                     10  ...                  0
# 5                     10                      0  ...                  0
# 6                    100                      0  ...                  0
# 1                     10                      0  ...                100
# 3                     10                     10  ...                  0
# 2                     10                      0  ...                100
# 4                     10                     10  ...                  0
# 7                     10                     10  ...                  0
#
#   param_bagging_fraction split0_test_score split1_test_score  \
# 9                      1           0.98025           0.97985
# 0                    0.5           0.97675           0.97795
# 8                      1           0.96760           0.96585
# 5                    0.5           0.96655           0.96685
# 6                    0.5           0.95475           0.95645
# 1                      1           0.95410           0.95535
# 3                    0.5           0.95440           0.95530
# 2                      1           0.95405           0.95535
# 4                    0.5           0.95430           0.95530
# 7                    0.5           0.95430           0.95530
#
#    split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 9            0.98165            0.97990            0.98255          0.98084
# 0            0.97805            0.97600            0.97925          0.97760
# 8            0.96800            0.96575            0.96955          0.96735
# 5            0.96775            0.96625            0.96925          0.96733
# 6            0.95635            0.95615            0.95885          0.95651
# 1            0.95735            0.95475            0.95850          0.95601
# 3            0.95640            0.95525            0.95750          0.95577
# 2            0.95580            0.95440            0.95805          0.95553
# 4            0.95605            0.95490            0.95710          0.95553
# 7            0.95605            0.95490            0.95710          0.95553
#
#    std_test_score  rank_test_score
# 9        0.001076                1
# 0        0.001125                2
# 8        0.001424                3
# 5        0.001083                4
# 6        0.001322                5
# 1        0.001653                6
# 3        0.001073                7
# 2        0.001409                8
# 4        0.000969                8
# 7        0.000969                8
#
# [10 rows x 22 columns]

# %%
model_lgb = grid_search.best_estimator_

# %%
param_grid = {'num_leaves': range(10, 200, 10), 'max_depth': range(3, 20, 5)}

# %%
grid_search = GridSearchCV(estimator=model_lgb, param_grid=param_grid, cv=cv_fold, scoring=f1)
grid_search.fit(X_train, y_train)

# %%
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# LGBMClassifier(bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.5,
#                max_depth=13, min_child_weight=10, min_data_in_leaf=10,
#                n_jobs=24, nthread=28, num_class=4, num_leaves=130,
#                objective='multiclass', reg_alpha=10, reg_lambda=10, seed=23,
#                verbose=-1)
# {'max_depth': 13, 'num_leaves': 130}
# 0.9810599999999999

# %%
model_lgb = grid_search.best_estimator_

# %%
model_lgb
# Out:
# LGBMClassifier(bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.5,
#                max_depth=13, min_child_weight=10, min_data_in_leaf=10,
#                n_jobs=24, nthread=28, num_class=4, num_leaves=130,
#                objective='multiclass', reg_alpha=10, reg_lambda=10, seed=23,
#                verbose=-1)

# %%
lgb_score = cross_val_score(model_lgb, X_train, y_train, cv=5, scoring=f1)

# %%
lgb_score
# Out:
# array([0.98185, 0.9817 , 0.98115, 0.9812 , 0.98055])

# %%
param_grid = {
    'depth': [4, 7, 10],
    'learning_rate' : [0.03, 0.1, 0.15],
    'l2_leaf_reg': [1,4,9],
    'iterations': [300, 500, 1200],
    'early_stopping_rounds': [300],
    'task_type':['GPU'],
    'loss_function':['MultiClass'],
}

# %%
y_train = y_train.astype(int)

# %%
from catboost import CatBoostClassifier

model_catbst = CatBoostClassifier()
grid_search = RandomizedSearchCV(estimator=model_catbst, param_distributions=param_grid, cv=cv_fold, scoring=f1)
grid_search.fit(X_train, y_train)

# %%
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# <catboost.core.CatBoostClassifier object at 0x000001AF8D60FC50>
# {'task_type': 'GPU', 'loss_function': 'MultiClass', 'learning_rate': 0.15, 'l2_leaf_reg': 9, 'iterations': 1200, 'early_stopping_rounds': 300, 'depth': 10}
# 0.98633

# %%
model_catbst = grid_search.best_estimator_

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = {
    'bootstrap': [True, False],
     'max_depth': range(1, 20),
     'max_features': ['auto', 'sqrt'],
     'min_samples_leaf': range(5, 50, 5),
     'min_samples_split': range(2, 20, 2),
     'n_estimators': range(10, 300, 30),
             }

# %%
model_rfc = RandomForestClassifier()
grid_search = RandomizedSearchCV(estimator=model_rfc, param_distributions=param_grid, cv=cv_fold, n_jobs=-1, verbose=1, scoring=f1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 10.6min finished
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=2021, shuffle=True),
#                    estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': range(1, 20),
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': range(5, 50, 5),
#                                         'min_samples_split': range(2, 20, 2),
#                                         'n_estimators': range(10, 300, 30)},
#                    scoring=make_scorer(f1_score, average=micro), verbose=1)

# %%
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# RandomForestClassifier(max_depth=16, min_samples_leaf=10, min_samples_split=14,
#                        n_estimators=250)
# {'n_estimators': 250, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': 'auto', 'max_depth': 16, 'bootstrap': True}
# 0.96485

# %%
model_rfc = grid_search.best_estimator_

# %%
pred_test_lgb = model_lgb.predict_proba(X_test)
pred_test_cat = model_catbst.predict_proba(X_test)
pred_test_rfc = model_rfc.predict_proba(X_test)

# %%
pred_test_all = 1/3 * pred_test_lgb + 1/3 * pred_test_cat + 1/3 * pred_test_rfc

# %%
# pred_test_all = np.where(pred_test_all==pred_test_all.max(axis=1, keepdims=1), 1, 0)

# %%
pred_test_all
# Out:
# array([[9.94342866e-01, 2.94359198e-03, 6.34052780e-04, 2.07948903e-03],
#        [6.23273783e-03, 1.60086811e-02, 9.76923295e-01, 8.35285742e-04],
#        [3.01286218e-03, 5.29911399e-05, 9.29845168e-03, 9.87635695e-01],
#        ...,
#        [2.48777223e-01, 8.74333133e-03, 7.31456412e-01, 1.10230340e-02],
#        [9.94787842e-01, 3.27794097e-03, 1.07380088e-03, 8.60416512e-04],
#        [8.14006901e-01, 3.39308022e-02, 7.38080572e-02, 7.82542396e-02]])

# %%
df = pd.read_csv('sample_submit.csv')

df[['label_0', 'label_1', 'label_2', 'label_3']] = pred_test_all

df.to_csv('submission_prob.csv', index=False)

# %% [markdown]
# # stacking

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('testA.csv')
train.head()
# Out:
#    id                                  heartbeat_signals  label
# 0   0  0.9912297987616655,0.9435330436439665,0.764677...    0.0
# 1   1  0.9714822034884503,0.9289687459588268,0.572932...    0.0
# 2   2  1.0,0.9591487564065292,0.7013782792997189,0.23...    2.0
# 3   3  0.9757952826275774,0.9340884687738161,0.659636...    0.0
# 4   4  0.0,0.055816398940721094,0.26129357194994196,0...    2.0

# %%
train = train.join(train['heartbeat_signals'].str.split(',').apply(pd.Series).astype('float'))
train.drop(columns='heartbeat_signals', inplace=True)
train = train.rename({i:f's_{i}' for i in range(205)}, axis=1)

test = test.join(test['heartbeat_signals'].str.split(',').apply(pd.Series).astype('float'))
test.drop(columns='heartbeat_signals', inplace=True)
test = test.rename({i:f's_{i}' for i in range(205)}, axis=1)

# %%
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 157.93 MB
# Memory usage after optimization is: 39.67 MB
# Decreased by 74.9%
# Memory usage of dataframe is 31.43 MB
# Memory usage after optimization is: 7.90 MB
# Decreased by 74.9%

# %%
train_X_data = train.drop(columns=['id', 'label'])
train_X_target = train['label'].astype(int)
X_test = test.drop(columns='id')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
def stacking(model, train_data, train_target, test_data, n_fold):
    skf = StratifiedKFold(n_splits=n_fold, random_state=1)  # StratifiedKFold 默认分层采样
    train_pred = np.zeros((train_data.shape[0], 1), int)   # 存储训练集预测结果
    test_pred = np.zeros((test_data.shape[0], 1), int)  # 存储测试集预测结果 行数：len(test_data) ,列数：1列
    for skf_index, (train_index, val_index) in enumerate(skf.split(train_data, train_target)):
        print('第 ', skf_index+1, ' 折交叉验证开始... ')
        # 训练集划分
        x_train, x_val = train_data.iloc[train_index], train_data.iloc[val_index]
        y_train, y_val = train_target.iloc[train_index], train_target.iloc[val_index]
        # 模型构建
        y_train = np.ravel(y_train)   # 向量转成数组
        model.fit(X=x_train, y=y_train)
        # 模型预测
        accs = accuracy_score(y_val, model.predict(x_val))
        print('第 ', skf_index+1, ' 折交叉验证 :  accuracy ： ', accs)
 
        # 训练集预测结果
        val_pred = model.predict(x_val)
        for i in range(len(val_index)):
            train_pred[val_index[i]] = val_pred[i]
        # 保存测试集预测结果
        test_pred = np.column_stack((test_pred, model.predict(test_data)))  # 将矩阵按列合并
 
    test_pred_mean = np.mean(test_pred, axis=1)  # 按行计算均值(会出现小数)
    test_pred_mean = pd.DataFrame(test_pred_mean)   # 转成DataFrame
    test_pred_mean = test_pred_mean.apply(lambda x: round(x))  # 小数需要四舍五入成整数
    return np.ravel(test_pred_mean), train_pred

# %%
x_train, x_test, y_train, y_test = train_test_split(train_X_data.values, train_X_target.values, test_size=0.3, random_state=1)
x_train = pd.DataFrame(x_train)
y_train = pd.DataFrame(y_train)
x_test = pd.DataFrame(X_test.values)

# LGBMClassifier
rf = LGBMClassifier(bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.5,
               max_depth=20, min_child_weight=10, min_data_in_leaf=10,
               n_jobs=24, nthread=28, num_class=4, num_leaves=200,
               objective='multiclass', reg_alpha=10, reg_lambda=10, seed=23,
               verbose=-1)
print('==============================LGBMClassifier==============================')
rf_test_pred, rf_train_pred = stacking(model=rf, train_data=x_train, train_target=y_train, test_data=x_test, n_fold=5)
rf_test_pred = pd.DataFrame(rf_test_pred)
print(rf_train_pred)
rf_train_pred = pd.DataFrame(rf_train_pred)

# CatBoostClassifier
dt = CatBoostClassifier(task_type='GPU', loss_function='MultiClass', learning_rate=0.15, 
                        l2_leaf_reg=9, iterations=600, early_stopping_rounds=300, depth=10)
print('==============================CatBoostClassifier==============================')
dt_test_pred, dt_train_pred = stacking(model=dt, train_data=x_train, train_target=y_train, test_data=x_test, n_fold=5)
dt_test_pred = pd.DataFrame(dt_test_pred)
dt_train_pred = pd.DataFrame(dt_train_pred)

# RandomForestClassifier
knn = RandomForestClassifier(max_depth=16, min_samples_leaf=10, min_samples_split=14,
                       n_estimators=250)
print('==============================RandomForestClassifier==============================')
knn_test_pred, knn_train_pred = stacking(model=knn, train_data=x_train, train_target=y_train, test_data=x_test, n_fold=5)
knn_test_pred = pd.DataFrame(knn_test_pred)
knn_train_pred = pd.DataFrame(knn_train_pred)

# rf_train_pred,dt_train_pred,knn_train_pred 合并生成次级训练集 train_set
# rf_test_pred,dt_test_pred,knn_test_pred 合并生成次级测试集集 test_set
train_set = pd.concat([rf_train_pred, dt_train_pred, knn_train_pred],  axis=1)
test_set = pd.concat([rf_test_pred, dt_test_pred, knn_test_pred],  axis=1)

clf = LogisticRegression(solver='lbfgs')
clf.fit(train_set, y_train)
y_submission = clf.predict(test_set)
# Out:
# ==============================LGBMClassifier==============================
# 第  1  折交叉验证开始...
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# 第  1  折交叉验证 :  accuracy ：  0.9772857142857143
# 第  2  折交叉验证开始...
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# 第  2  折交叉验证 :  accuracy ：  0.9775714285714285
# 第  3  折交叉验证开始...
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# 第  3  折交叉验证 :  accuracy ：  0.9797857142857143
# 第  4  折交叉验证开始...
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# 第  4  折交叉验证 :  accuracy ：  0.9778571428571429
# 第  5  折交叉验证开始...
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# 第  5  折交叉验证 :  accuracy ：  0.979
# [[2]
#  [2]
#  [3]
#  ...
#  [3]
#  [0]
#  [2]]
# ==============================CatBoostClassifier==============================
# 第  1  折交叉验证开始...
# 0:	learn: 1.0708810	total: 82ms	remaining: 49.1s
# 1:	learn: 0.8815917	total: 158ms	remaining: 47.2s
# 2:	learn: 0.7482107	total: 242ms	remaining: 48.1s
# 3:	learn: 0.6493685	total: 321ms	remaining: 47.9s
# 4:	learn: 0.5729787	total: 399ms	remaining: 47.4s
# 5:	learn: 0.5116835	total: 476ms	remaining: 47.1s
# 6:	learn: 0.4614295	total: 559ms	remaining: 47.4s
# 7:	learn: 0.4188251	total: 641ms	remaining: 47.4s
# 8:	learn: 0.3822514	total: 722ms	remaining: 47.4s
# 9:	learn: 0.3522395	total: 799ms	remaining: 47.1s
# 10:	learn: 0.3266627	total: 879ms	remaining: 47s
# 11:	learn: 0.3043195	total: 953ms	remaining: 46.7s
# 12:	learn: 0.2855765	total: 1.03s	remaining: 46.5s
# 13:	learn: 0.2684184	total: 1.11s	remaining: 46.5s
# 14:	learn: 0.2551569	total: 1.19s	remaining: 46.2s
# 15:	learn: 0.2431064	total: 1.26s	remaining: 46s
# 16:	learn: 0.2304298	total: 1.34s	remaining: 46.2s
# 17:	learn: 0.2187695	total: 1.43s	remaining: 46.2s
# 18:	learn: 0.2091399	total: 1.51s	remaining: 46.2s
# 19:	learn: 0.2016990	total: 1.59s	remaining: 46.3s
# 20:	learn: 0.1953020	total: 1.67s	remaining: 46.1s
# 21:	learn: 0.1880834	total: 1.75s	remaining: 46s
# 22:	learn: 0.1826299	total: 1.84s	remaining: 46.1s
# 23:	learn: 0.1771822	total: 1.92s	remaining: 46s
# 24:	learn: 0.1719092	total: 2s	remaining: 45.9s
# 25:	learn: 0.1663894	total: 2.07s	remaining: 45.8s
# 26:	learn: 0.1624570	total: 2.14s	remaining: 45.4s
# 27:	learn: 0.1587802	total: 2.22s	remaining: 45.4s
# 28:	learn: 0.1557781	total: 2.3s	remaining: 45.3s
# 29:	learn: 0.1517245	total: 2.38s	remaining: 45.2s
# 30:	learn: 0.1490700	total: 2.45s	remaining: 44.9s
# 31:	learn: 0.1457445	total: 2.53s	remaining: 44.9s
# 32:	learn: 0.1432329	total: 2.6s	remaining: 44.7s
# 33:	learn: 0.1401881	total: 2.68s	remaining: 44.6s
# 34:	learn: 0.1375039	total: 2.76s	remaining: 44.5s
# 35:	learn: 0.1355442	total: 2.83s	remaining: 44.3s
# 36:	learn: 0.1328409	total: 2.91s	remaining: 44.2s
# 37:	learn: 0.1305119	total: 2.98s	remaining: 44.2s
# 38:	learn: 0.1286067	total: 3.06s	remaining: 44s
# 39:	learn: 0.1264961	total: 3.13s	remaining: 43.9s
# 40:	learn: 0.1244988	total: 3.21s	remaining: 43.8s
# 41:	learn: 0.1223381	total: 3.29s	remaining: 43.7s
# 42:	learn: 0.1205171	total: 3.36s	remaining: 43.6s
# 43:	learn: 0.1187474	total: 3.44s	remaining: 43.5s
# 44:	learn: 0.1171920	total: 3.51s	remaining: 43.3s
# 45:	learn: 0.1164124	total: 3.58s	remaining: 43.1s
# 46:	learn: 0.1150324	total: 3.65s	remaining: 43s
# 47:	learn: 0.1130728	total: 3.73s	remaining: 42.9s
# 48:	learn: 0.1116270	total: 3.81s	remaining: 42.8s
# 49:	learn: 0.1109210	total: 3.88s	remaining: 42.6s
# 50:	learn: 0.1093894	total: 3.95s	remaining: 42.5s
# 51:	learn: 0.1085717	total: 4.03s	remaining: 42.5s
# 52:	learn: 0.1077093	total: 4.09s	remaining: 42.3s
# 53:	learn: 0.1067064	total: 4.16s	remaining: 42.1s
# 54:	learn: 0.1059645	total: 4.24s	remaining: 42s
# 55:	learn: 0.1052676	total: 4.3s	remaining: 41.8s
# 56:	learn: 0.1039149	total: 4.38s	remaining: 41.8s
# 57:	learn: 0.1031529	total: 4.46s	remaining: 41.7s
# 58:	learn: 0.1020649	total: 4.54s	remaining: 41.6s
# 59:	learn: 0.1016425	total: 4.61s	remaining: 41.5s
# 60:	learn: 0.1006161	total: 4.69s	remaining: 41.4s
# 61:	learn: 0.0996517	total: 4.76s	remaining: 41.3s
# 62:	learn: 0.0991615	total: 4.82s	remaining: 41.1s
# 63:	learn: 0.0980184	total: 4.9s	remaining: 41.1s
# 64:	learn: 0.0971340	total: 4.97s	remaining: 40.9s
# 65:	learn: 0.0959905	total: 5.05s	remaining: 40.9s
# 66:	learn: 0.0952064	total: 5.12s	remaining: 40.8s
# 67:	learn: 0.0944054	total: 5.19s	remaining: 40.6s
# 68:	learn: 0.0934949	total: 5.26s	remaining: 40.5s
# 69:	learn: 0.0929754	total: 5.33s	remaining: 40.4s
# 70:	learn: 0.0923161	total: 5.41s	remaining: 40.3s
# 71:	learn: 0.0916772	total: 5.48s	remaining: 40.2s
# 72:	learn: 0.0911439	total: 5.54s	remaining: 40s
# 73:	learn: 0.0902756	total: 5.62s	remaining: 40s
# 74:	learn: 0.0898632	total: 5.69s	remaining: 39.8s
# 75:	learn: 0.0890412	total: 5.78s	remaining: 39.8s
# 76:	learn: 0.0887622	total: 5.84s	remaining: 39.7s
# 77:	learn: 0.0881979	total: 5.92s	remaining: 39.6s
# 78:	learn: 0.0877206	total: 5.98s	remaining: 39.4s
# 79:	learn: 0.0873811	total: 6.05s	remaining: 39.3s
# 80:	learn: 0.0868796	total: 6.11s	remaining: 39.2s
# 81:	learn: 0.0863187	total: 6.18s	remaining: 39.1s
# 82:	learn: 0.0860284	total: 6.25s	remaining: 39s
# 83:	learn: 0.0857267	total: 6.32s	remaining: 38.8s
# 84:	learn: 0.0854681	total: 6.38s	remaining: 38.7s
# 85:	learn: 0.0848366	total: 6.45s	remaining: 38.6s
# 86:	learn: 0.0843911	total: 6.52s	remaining: 38.5s
# 87:	learn: 0.0841607	total: 6.59s	remaining: 38.3s
# 88:	learn: 0.0835585	total: 6.66s	remaining: 38.2s
# 89:	learn: 0.0830354	total: 6.73s	remaining: 38.1s
# 90:	learn: 0.0824996	total: 6.8s	remaining: 38s
# 91:	learn: 0.0821217	total: 6.86s	remaining: 37.9s
# 92:	learn: 0.0818629	total: 6.93s	remaining: 37.8s
# 93:	learn: 0.0816314	total: 7s	remaining: 37.7s
# 94:	learn: 0.0813243	total: 7.07s	remaining: 37.6s
# 95:	learn: 0.0811990	total: 7.14s	remaining: 37.5s
# 96:	learn: 0.0808453	total: 7.21s	remaining: 37.4s
# 97:	learn: 0.0802848	total: 7.28s	remaining: 37.3s
# 98:	learn: 0.0800103	total: 7.35s	remaining: 37.2s
# 99:	learn: 0.0799647	total: 7.41s	remaining: 37s
# 100:	learn: 0.0794806	total: 7.48s	remaining: 37s
# 101:	learn: 0.0792775	total: 7.54s	remaining: 36.8s
# 102:	learn: 0.0786260	total: 7.62s	remaining: 36.8s
# 103:	learn: 0.0784839	total: 7.69s	remaining: 36.7s
# 104:	learn: 0.0780620	total: 7.76s	remaining: 36.6s
# 105:	learn: 0.0776257	total: 7.83s	remaining: 36.5s
# 106:	learn: 0.0774676	total: 7.89s	remaining: 36.4s
# 107:	learn: 0.0771838	total: 7.96s	remaining: 36.3s
# 108:	learn: 0.0770358	total: 8.02s	remaining: 36.1s
# 109:	learn: 0.0768420	total: 8.08s	remaining: 36s
# 110:	learn: 0.0762750	total: 8.15s	remaining: 35.9s
# 111:	learn: 0.0762454	total: 8.21s	remaining: 35.8s
# 112:	learn: 0.0760507	total: 8.27s	remaining: 35.7s
# 113:	learn: 0.0757318	total: 8.34s	remaining: 35.6s
# 114:	learn: 0.0751155	total: 8.42s	remaining: 35.5s
# 115:	learn: 0.0747017	total: 8.49s	remaining: 35.4s
# 116:	learn: 0.0741886	total: 8.56s	remaining: 35.3s
# 117:	learn: 0.0739570	total: 8.63s	remaining: 35.2s
# 118:	learn: 0.0737742	total: 8.69s	remaining: 35.1s
# 119:	learn: 0.0733756	total: 8.77s	remaining: 35.1s
# 120:	learn: 0.0731720	total: 8.83s	remaining: 35s
# 121:	learn: 0.0728764	total: 8.9s	remaining: 34.9s
# 122:	learn: 0.0726177	total: 8.96s	remaining: 34.8s
# 123:	learn: 0.0722717	total: 9.04s	remaining: 34.7s
# 124:	learn: 0.0719648	total: 9.11s	remaining: 34.6s
# 125:	learn: 0.0718204	total: 9.17s	remaining: 34.5s
# 126:	learn: 0.0716568	total: 9.24s	remaining: 34.4s
# 127:	learn: 0.0711958	total: 9.31s	remaining: 34.3s
# 128:	learn: 0.0710472	total: 9.38s	remaining: 34.2s
# 129:	learn: 0.0706562	total: 9.45s	remaining: 34.2s
# 130:	learn: 0.0704106	total: 9.51s	remaining: 34.1s
# 131:	learn: 0.0701187	total: 9.58s	remaining: 34s
# 132:	learn: 0.0700994	total: 9.64s	remaining: 33.8s
# 133:	learn: 0.0698928	total: 9.71s	remaining: 33.8s
# 134:	learn: 0.0695193	total: 9.78s	remaining: 33.7s
# 135:	learn: 0.0692156	total: 9.85s	remaining: 33.6s
# 136:	learn: 0.0690990	total: 9.91s	remaining: 33.5s
# 137:	learn: 0.0690569	total: 9.97s	remaining: 33.4s
# 138:	learn: 0.0687529	total: 10s	remaining: 33.3s
# 139:	learn: 0.0685649	total: 10.1s	remaining: 33.2s
# 140:	learn: 0.0682701	total: 10.2s	remaining: 33.1s
# 141:	learn: 0.0680592	total: 10.2s	remaining: 33s
# 142:	learn: 0.0678000	total: 10.3s	remaining: 33s
# 143:	learn: 0.0676194	total: 10.4s	remaining: 32.9s
# 144:	learn: 0.0672675	total: 10.5s	remaining: 32.8s
# 145:	learn: 0.0670197	total: 10.5s	remaining: 32.7s
# 146:	learn: 0.0668289	total: 10.6s	remaining: 32.6s
# 147:	learn: 0.0666579	total: 10.7s	remaining: 32.6s
# 148:	learn: 0.0665288	total: 10.7s	remaining: 32.5s
# 149:	learn: 0.0663595	total: 10.8s	remaining: 32.4s
# 150:	learn: 0.0660819	total: 10.9s	remaining: 32.3s
# 151:	learn: 0.0656941	total: 10.9s	remaining: 32.2s
# 152:	learn: 0.0653438	total: 11s	remaining: 32.2s
# 153:	learn: 0.0649868	total: 11.1s	remaining: 32.1s
# 154:	learn: 0.0648091	total: 11.1s	remaining: 32s
# 155:	learn: 0.0645492	total: 11.2s	remaining: 31.9s
# 156:	learn: 0.0641389	total: 11.3s	remaining: 31.9s
# 157:	learn: 0.0640477	total: 11.4s	remaining: 31.8s
# 158:	learn: 0.0638598	total: 11.4s	remaining: 31.7s
# 159:	learn: 0.0636163	total: 11.5s	remaining: 31.6s
# 160:	learn: 0.0634053	total: 11.6s	remaining: 31.5s
# 161:	learn: 0.0633329	total: 11.6s	remaining: 31.4s
# 162:	learn: 0.0632137	total: 11.7s	remaining: 31.4s
# 163:	learn: 0.0629475	total: 11.8s	remaining: 31.3s
# 164:	learn: 0.0627728	total: 11.8s	remaining: 31.2s
# 165:	learn: 0.0624704	total: 11.9s	remaining: 31.2s
# 166:	learn: 0.0622372	total: 12s	remaining: 31.1s
# 167:	learn: 0.0621376	total: 12s	remaining: 31s
# 168:	learn: 0.0619027	total: 12.1s	remaining: 30.9s
# 169:	learn: 0.0617101	total: 12.2s	remaining: 30.8s
# 170:	learn: 0.0614860	total: 12.3s	remaining: 30.8s
# 171:	learn: 0.0611465	total: 12.3s	remaining: 30.7s
# 172:	learn: 0.0610133	total: 12.4s	remaining: 30.6s
# 173:	learn: 0.0609025	total: 12.5s	remaining: 30.5s
# 174:	learn: 0.0606809	total: 12.5s	remaining: 30.5s
# 175:	learn: 0.0605457	total: 12.6s	remaining: 30.4s
# 176:	learn: 0.0601884	total: 12.7s	remaining: 30.3s
# 177:	learn: 0.0601243	total: 12.7s	remaining: 30.2s
# 178:	learn: 0.0599510	total: 12.8s	remaining: 30.1s
# 179:	learn: 0.0597180	total: 12.9s	remaining: 30s
# 180:	learn: 0.0596983	total: 12.9s	remaining: 29.9s
# 181:	learn: 0.0595910	total: 13s	remaining: 29.9s
# 182:	learn: 0.0595504	total: 13.1s	remaining: 29.8s
# 183:	learn: 0.0593540	total: 13.1s	remaining: 29.7s
# 184:	learn: 0.0592668	total: 13.2s	remaining: 29.6s
# 185:	learn: 0.0588633	total: 13.3s	remaining: 29.6s
# 186:	learn: 0.0584677	total: 13.4s	remaining: 29.5s
# 187:	learn: 0.0583301	total: 13.4s	remaining: 29.4s
# 188:	learn: 0.0583124	total: 13.5s	remaining: 29.3s
# 189:	learn: 0.0581271	total: 13.5s	remaining: 29.2s
# 190:	learn: 0.0579626	total: 13.6s	remaining: 29.2s
# 191:	learn: 0.0578835	total: 13.7s	remaining: 29.1s
# 192:	learn: 0.0576469	total: 13.7s	remaining: 29s
# 193:	learn: 0.0576154	total: 13.8s	remaining: 28.9s
# 194:	learn: 0.0573162	total: 13.9s	remaining: 28.8s
# 195:	learn: 0.0571199	total: 13.9s	remaining: 28.7s
# 196:	learn: 0.0570173	total: 14s	remaining: 28.7s
# 197:	learn: 0.0569453	total: 14.1s	remaining: 28.6s
# 198:	learn: 0.0568028	total: 14.1s	remaining: 28.5s
# 199:	learn: 0.0565760	total: 14.2s	remaining: 28.4s
# 200:	learn: 0.0564000	total: 14.3s	remaining: 28.3s
# 201:	learn: 0.0563660	total: 14.3s	remaining: 28.2s
# 202:	learn: 0.0562381	total: 14.4s	remaining: 28.2s
# 203:	learn: 0.0561928	total: 14.5s	remaining: 28.1s
# 204:	learn: 0.0561189	total: 14.5s	remaining: 28s
# 205:	learn: 0.0559188	total: 14.6s	remaining: 27.9s
# 206:	learn: 0.0557402	total: 14.7s	remaining: 27.9s
# 207:	learn: 0.0556948	total: 14.7s	remaining: 27.8s
# 208:	learn: 0.0555599	total: 14.8s	remaining: 27.7s
# 209:	learn: 0.0553900	total: 14.9s	remaining: 27.6s
# 210:	learn: 0.0551696	total: 15s	remaining: 27.6s
# 211:	learn: 0.0550448	total: 15s	remaining: 27.5s
# 212:	learn: 0.0550208	total: 15.1s	remaining: 27.4s
# 213:	learn: 0.0549783	total: 15.1s	remaining: 27.3s
# 214:	learn: 0.0549455	total: 15.2s	remaining: 27.2s
# 215:	learn: 0.0548372	total: 15.3s	remaining: 27.2s
# 216:	learn: 0.0547466	total: 15.3s	remaining: 27.1s
# 217:	learn: 0.0545403	total: 15.4s	remaining: 27s
# 218:	learn: 0.0542510	total: 15.5s	remaining: 27s
# 219:	learn: 0.0540879	total: 15.6s	remaining: 26.9s
# 220:	learn: 0.0539937	total: 15.6s	remaining: 26.8s
# 221:	learn: 0.0538409	total: 15.7s	remaining: 26.7s
# 222:	learn: 0.0538141	total: 15.8s	remaining: 26.6s
# 223:	learn: 0.0537365	total: 15.8s	remaining: 26.6s
# 224:	learn: 0.0534488	total: 15.9s	remaining: 26.5s
# 225:	learn: 0.0534090	total: 16s	remaining: 26.4s
# 226:	learn: 0.0532880	total: 16s	remaining: 26.3s
# 227:	learn: 0.0532490	total: 16.1s	remaining: 26.3s
# 228:	learn: 0.0531124	total: 16.2s	remaining: 26.2s
# 229:	learn: 0.0529747	total: 16.2s	remaining: 26.1s
# 230:	learn: 0.0528522	total: 16.3s	remaining: 26s
# 231:	learn: 0.0528448	total: 16.4s	remaining: 25.9s
# 232:	learn: 0.0525835	total: 16.4s	remaining: 25.9s
# 233:	learn: 0.0524264	total: 16.5s	remaining: 25.8s
# 234:	learn: 0.0523931	total: 16.6s	remaining: 25.7s
# 235:	learn: 0.0522769	total: 16.6s	remaining: 25.7s
# 236:	learn: 0.0522442	total: 16.7s	remaining: 25.6s
# 237:	learn: 0.0521469	total: 16.8s	remaining: 25.5s
# 238:	learn: 0.0518648	total: 16.8s	remaining: 25.4s
# 239:	learn: 0.0517308	total: 16.9s	remaining: 25.4s
# 240:	learn: 0.0515726	total: 17s	remaining: 25.3s
# 241:	learn: 0.0513967	total: 17.1s	remaining: 25.2s
# 242:	learn: 0.0511891	total: 17.1s	remaining: 25.2s
# 243:	learn: 0.0511076	total: 17.2s	remaining: 25.1s
# 244:	learn: 0.0508543	total: 17.3s	remaining: 25s
# 245:	learn: 0.0507423	total: 17.3s	remaining: 24.9s
# 246:	learn: 0.0506581	total: 17.4s	remaining: 24.9s
# 247:	learn: 0.0505760	total: 17.5s	remaining: 24.8s
# 248:	learn: 0.0504757	total: 17.5s	remaining: 24.7s
# 249:	learn: 0.0502516	total: 17.6s	remaining: 24.6s
# 250:	learn: 0.0501316	total: 17.7s	remaining: 24.6s
# 251:	learn: 0.0500340	total: 17.7s	remaining: 24.5s
# 252:	learn: 0.0498685	total: 17.8s	remaining: 24.4s
# 253:	learn: 0.0497183	total: 17.9s	remaining: 24.3s
# 254:	learn: 0.0495546	total: 17.9s	remaining: 24.3s
# 255:	learn: 0.0494906	total: 18s	remaining: 24.2s
# 256:	learn: 0.0494714	total: 18.1s	remaining: 24.1s
# 257:	learn: 0.0493959	total: 18.1s	remaining: 24s
# 258:	learn: 0.0492647	total: 18.2s	remaining: 24s
# 259:	learn: 0.0490578	total: 18.3s	remaining: 23.9s
# 260:	learn: 0.0489454	total: 18.3s	remaining: 23.8s
# 261:	learn: 0.0487794	total: 18.4s	remaining: 23.8s
# 262:	learn: 0.0487140	total: 18.5s	remaining: 23.7s
# 263:	learn: 0.0486544	total: 18.5s	remaining: 23.6s
# 264:	learn: 0.0486243	total: 18.6s	remaining: 23.5s
# 265:	learn: 0.0485644	total: 18.7s	remaining: 23.4s
# 266:	learn: 0.0484823	total: 18.7s	remaining: 23.4s
# 267:	learn: 0.0484325	total: 18.8s	remaining: 23.3s
# 268:	learn: 0.0484141	total: 18.9s	remaining: 23.2s
# 269:	learn: 0.0483994	total: 18.9s	remaining: 23.1s
# 270:	learn: 0.0482750	total: 19s	remaining: 23s
# 271:	learn: 0.0482177	total: 19s	remaining: 23s
# 272:	learn: 0.0481861	total: 19.1s	remaining: 22.9s
# 273:	learn: 0.0480158	total: 19.2s	remaining: 22.8s
# 274:	learn: 0.0479139	total: 19.2s	remaining: 22.7s
# 275:	learn: 0.0478852	total: 19.3s	remaining: 22.7s
# 276:	learn: 0.0477528	total: 19.4s	remaining: 22.6s
# 277:	learn: 0.0476908	total: 19.4s	remaining: 22.5s
# 278:	learn: 0.0476493	total: 19.5s	remaining: 22.4s
# 279:	learn: 0.0475595	total: 19.6s	remaining: 22.4s
# 280:	learn: 0.0474949	total: 19.6s	remaining: 22.3s
# 281:	learn: 0.0473529	total: 19.7s	remaining: 22.2s
# 282:	learn: 0.0472194	total: 19.8s	remaining: 22.2s
# 283:	learn: 0.0471608	total: 19.9s	remaining: 22.1s
# 284:	learn: 0.0471053	total: 19.9s	remaining: 22s
# 285:	learn: 0.0470223	total: 20s	remaining: 21.9s
# 286:	learn: 0.0469600	total: 20.1s	remaining: 21.9s
# 287:	learn: 0.0468585	total: 20.1s	remaining: 21.8s
# 288:	learn: 0.0466960	total: 20.2s	remaining: 21.7s
# 289:	learn: 0.0465836	total: 20.3s	remaining: 21.7s
# 290:	learn: 0.0465536	total: 20.3s	remaining: 21.6s
# 291:	learn: 0.0464390	total: 20.4s	remaining: 21.5s
# 292:	learn: 0.0464318	total: 20.4s	remaining: 21.4s
# 293:	learn: 0.0464142	total: 20.5s	remaining: 21.3s
# 294:	learn: 0.0462977	total: 20.6s	remaining: 21.3s
# 295:	learn: 0.0462268	total: 20.6s	remaining: 21.2s
# 296:	learn: 0.0461243	total: 20.7s	remaining: 21.1s
# 297:	learn: 0.0460660	total: 20.8s	remaining: 21.1s
# 298:	learn: 0.0460578	total: 20.8s	remaining: 21s
# 299:	learn: 0.0460210	total: 20.9s	remaining: 20.9s
# 300:	learn: 0.0459250	total: 21s	remaining: 20.8s
# 301:	learn: 0.0458420	total: 21s	remaining: 20.8s
# 302:	learn: 0.0458231	total: 21.1s	remaining: 20.7s
# 303:	learn: 0.0457657	total: 21.2s	remaining: 20.6s
# 304:	learn: 0.0457468	total: 21.2s	remaining: 20.5s
# 305:	learn: 0.0455786	total: 21.3s	remaining: 20.5s
# 306:	learn: 0.0454962	total: 21.4s	remaining: 20.4s
# 307:	learn: 0.0454052	total: 21.4s	remaining: 20.3s
# 308:	learn: 0.0452612	total: 21.5s	remaining: 20.2s
# 309:	learn: 0.0451318	total: 21.6s	remaining: 20.2s
# 310:	learn: 0.0451067	total: 21.6s	remaining: 20.1s
# 311:	learn: 0.0450911	total: 21.7s	remaining: 20s
# 312:	learn: 0.0449923	total: 21.8s	remaining: 20s
# 313:	learn: 0.0449738	total: 21.8s	remaining: 19.9s
# 314:	learn: 0.0448591	total: 21.9s	remaining: 19.8s
# 315:	learn: 0.0448211	total: 22s	remaining: 19.7s
# 316:	learn: 0.0447160	total: 22s	remaining: 19.7s
# 317:	learn: 0.0446514	total: 22.1s	remaining: 19.6s
# 318:	learn: 0.0445606	total: 22.2s	remaining: 19.5s
# 319:	learn: 0.0444670	total: 22.2s	remaining: 19.5s
# 320:	learn: 0.0443215	total: 22.3s	remaining: 19.4s
# 321:	learn: 0.0442192	total: 22.4s	remaining: 19.3s
# 322:	learn: 0.0441123	total: 22.4s	remaining: 19.2s
# 323:	learn: 0.0439780	total: 22.5s	remaining: 19.2s
# 324:	learn: 0.0439595	total: 22.6s	remaining: 19.1s
# 325:	learn: 0.0438996	total: 22.6s	remaining: 19s
# 326:	learn: 0.0438508	total: 22.7s	remaining: 19s
# 327:	learn: 0.0437981	total: 22.8s	remaining: 18.9s
# 328:	learn: 0.0436788	total: 22.8s	remaining: 18.8s
# 329:	learn: 0.0436254	total: 22.9s	remaining: 18.7s
# 330:	learn: 0.0436017	total: 23s	remaining: 18.7s
# 331:	learn: 0.0435832	total: 23s	remaining: 18.6s
# 332:	learn: 0.0435154	total: 23.1s	remaining: 18.5s
# 333:	learn: 0.0434920	total: 23.2s	remaining: 18.5s
# 334:	learn: 0.0433367	total: 23.2s	remaining: 18.4s
# 335:	learn: 0.0432274	total: 23.3s	remaining: 18.3s
# 336:	learn: 0.0431020	total: 23.4s	remaining: 18.2s
# 337:	learn: 0.0429953	total: 23.4s	remaining: 18.2s
# 338:	learn: 0.0429725	total: 23.5s	remaining: 18.1s
# 339:	learn: 0.0429214	total: 23.6s	remaining: 18s
# 340:	learn: 0.0428370	total: 23.6s	remaining: 18s
# 341:	learn: 0.0427122	total: 23.7s	remaining: 17.9s
# 342:	learn: 0.0426871	total: 23.8s	remaining: 17.8s
# 343:	learn: 0.0425843	total: 23.9s	remaining: 17.8s
# 344:	learn: 0.0424836	total: 23.9s	remaining: 17.7s
# 345:	learn: 0.0423991	total: 24s	remaining: 17.6s
# 346:	learn: 0.0422735	total: 24.1s	remaining: 17.6s
# 347:	learn: 0.0422126	total: 24.1s	remaining: 17.5s
# 348:	learn: 0.0421122	total: 24.2s	remaining: 17.4s
# 349:	learn: 0.0420801	total: 24.3s	remaining: 17.3s
# 350:	learn: 0.0420340	total: 24.3s	remaining: 17.3s
# 351:	learn: 0.0419812	total: 24.4s	remaining: 17.2s
# 352:	learn: 0.0419156	total: 24.5s	remaining: 17.1s
# 353:	learn: 0.0418691	total: 24.5s	remaining: 17.1s
# 354:	learn: 0.0417639	total: 24.6s	remaining: 17s
# 355:	learn: 0.0416369	total: 24.7s	remaining: 16.9s
# 356:	learn: 0.0415655	total: 24.8s	remaining: 16.8s
# 357:	learn: 0.0415308	total: 24.8s	remaining: 16.8s
# 358:	learn: 0.0414620	total: 24.9s	remaining: 16.7s
# 359:	learn: 0.0414318	total: 24.9s	remaining: 16.6s
# 360:	learn: 0.0413518	total: 25s	remaining: 16.6s
# 361:	learn: 0.0412815	total: 25.1s	remaining: 16.5s
# 362:	learn: 0.0412595	total: 25.1s	remaining: 16.4s
# 363:	learn: 0.0411882	total: 25.2s	remaining: 16.3s
# 364:	learn: 0.0410471	total: 25.3s	remaining: 16.3s
# 365:	learn: 0.0410082	total: 25.4s	remaining: 16.2s
# 366:	learn: 0.0409509	total: 25.4s	remaining: 16.1s
# 367:	learn: 0.0408380	total: 25.5s	remaining: 16.1s
# 368:	learn: 0.0407026	total: 25.6s	remaining: 16s
# 369:	learn: 0.0406342	total: 25.6s	remaining: 15.9s
# 370:	learn: 0.0405538	total: 25.7s	remaining: 15.9s
# 371:	learn: 0.0405234	total: 25.8s	remaining: 15.8s
# 372:	learn: 0.0404723	total: 25.8s	remaining: 15.7s
# 373:	learn: 0.0404674	total: 25.9s	remaining: 15.6s
# 374:	learn: 0.0403626	total: 26s	remaining: 15.6s
# 375:	learn: 0.0403103	total: 26s	remaining: 15.5s
# 376:	learn: 0.0402918	total: 26.1s	remaining: 15.4s
# 377:	learn: 0.0402435	total: 26.1s	remaining: 15.4s
# 378:	learn: 0.0400998	total: 26.2s	remaining: 15.3s
# 379:	learn: 0.0400219	total: 26.3s	remaining: 15.2s
# 380:	learn: 0.0399504	total: 26.4s	remaining: 15.2s
# 381:	learn: 0.0399157	total: 26.4s	remaining: 15.1s
# 382:	learn: 0.0398409	total: 26.5s	remaining: 15s
# 383:	learn: 0.0397866	total: 26.6s	remaining: 14.9s
# 384:	learn: 0.0396669	total: 26.6s	remaining: 14.9s
# 385:	learn: 0.0396137	total: 26.7s	remaining: 14.8s
# 386:	learn: 0.0395319	total: 26.8s	remaining: 14.7s
# 387:	learn: 0.0394992	total: 26.8s	remaining: 14.7s
# 388:	learn: 0.0394489	total: 26.9s	remaining: 14.6s
# 389:	learn: 0.0392852	total: 27s	remaining: 14.5s
# 390:	learn: 0.0392762	total: 27s	remaining: 14.5s
# 391:	learn: 0.0392145	total: 27.1s	remaining: 14.4s
# 392:	learn: 0.0391186	total: 27.2s	remaining: 14.3s
# 393:	learn: 0.0390437	total: 27.2s	remaining: 14.2s
# 394:	learn: 0.0390028	total: 27.3s	remaining: 14.2s
# 395:	learn: 0.0388964	total: 27.4s	remaining: 14.1s
# 396:	learn: 0.0388479	total: 27.4s	remaining: 14s
# 397:	learn: 0.0387015	total: 27.5s	remaining: 14s
# 398:	learn: 0.0386616	total: 27.6s	remaining: 13.9s
# 399:	learn: 0.0386104	total: 27.6s	remaining: 13.8s
# 400:	learn: 0.0385745	total: 27.7s	remaining: 13.8s
# 401:	learn: 0.0385384	total: 27.8s	remaining: 13.7s
# 402:	learn: 0.0385296	total: 27.8s	remaining: 13.6s
# 403:	learn: 0.0383958	total: 27.9s	remaining: 13.5s
# 404:	learn: 0.0383667	total: 28s	remaining: 13.5s
# 405:	learn: 0.0383514	total: 28s	remaining: 13.4s
# 406:	learn: 0.0383416	total: 28.1s	remaining: 13.3s
# 407:	learn: 0.0382202	total: 28.2s	remaining: 13.3s
# 408:	learn: 0.0381465	total: 28.2s	remaining: 13.2s
# 409:	learn: 0.0380886	total: 28.3s	remaining: 13.1s
# 410:	learn: 0.0380312	total: 28.4s	remaining: 13.1s
# 411:	learn: 0.0379361	total: 28.4s	remaining: 13s
# 412:	learn: 0.0378518	total: 28.5s	remaining: 12.9s
# 413:	learn: 0.0378051	total: 28.6s	remaining: 12.8s
# 414:	learn: 0.0377827	total: 28.6s	remaining: 12.8s
# 415:	learn: 0.0377703	total: 28.7s	remaining: 12.7s
# 416:	learn: 0.0377443	total: 28.8s	remaining: 12.6s
# 417:	learn: 0.0376853	total: 28.8s	remaining: 12.6s
# 418:	learn: 0.0376658	total: 28.9s	remaining: 12.5s
# 419:	learn: 0.0376096	total: 29s	remaining: 12.4s
# 420:	learn: 0.0375780	total: 29s	remaining: 12.3s
# 421:	learn: 0.0375595	total: 29.1s	remaining: 12.3s
# 422:	learn: 0.0373667	total: 29.2s	remaining: 12.2s
# 423:	learn: 0.0372592	total: 29.2s	remaining: 12.1s
# 424:	learn: 0.0372324	total: 29.3s	remaining: 12.1s
# 425:	learn: 0.0372131	total: 29.4s	remaining: 12s
# 426:	learn: 0.0371903	total: 29.4s	remaining: 11.9s
# 427:	learn: 0.0371207	total: 29.5s	remaining: 11.9s
# 428:	learn: 0.0370962	total: 29.6s	remaining: 11.8s
# 429:	learn: 0.0370715	total: 29.6s	remaining: 11.7s
# 430:	learn: 0.0369844	total: 29.7s	remaining: 11.6s
# 431:	learn: 0.0369271	total: 29.8s	remaining: 11.6s
# 432:	learn: 0.0368618	total: 29.8s	remaining: 11.5s
# 433:	learn: 0.0368214	total: 29.9s	remaining: 11.4s
# 434:	learn: 0.0367739	total: 29.9s	remaining: 11.4s
# 435:	learn: 0.0367550	total: 30s	remaining: 11.3s
# 436:	learn: 0.0367049	total: 30.1s	remaining: 11.2s
# 437:	learn: 0.0366438	total: 30.1s	remaining: 11.1s
# 438:	learn: 0.0366051	total: 30.2s	remaining: 11.1s
# 439:	learn: 0.0365764	total: 30.3s	remaining: 11s
# 440:	learn: 0.0365684	total: 30.3s	remaining: 10.9s
# 441:	learn: 0.0365003	total: 30.4s	remaining: 10.9s
# 442:	learn: 0.0364500	total: 30.5s	remaining: 10.8s
# 443:	learn: 0.0364098	total: 30.5s	remaining: 10.7s
# 444:	learn: 0.0363525	total: 30.6s	remaining: 10.7s
# 445:	learn: 0.0363123	total: 30.7s	remaining: 10.6s
# 446:	learn: 0.0362599	total: 30.7s	remaining: 10.5s
# 447:	learn: 0.0361623	total: 30.8s	remaining: 10.4s
# 448:	learn: 0.0361007	total: 30.9s	remaining: 10.4s
# 449:	learn: 0.0360402	total: 30.9s	remaining: 10.3s
# 450:	learn: 0.0359702	total: 31s	remaining: 10.2s
# 451:	learn: 0.0359139	total: 31.1s	remaining: 10.2s
# 452:	learn: 0.0358209	total: 31.1s	remaining: 10.1s
# 453:	learn: 0.0357977	total: 31.2s	remaining: 10s
# 454:	learn: 0.0357717	total: 31.3s	remaining: 9.96s
# 455:	learn: 0.0357442	total: 31.3s	remaining: 9.89s
# 456:	learn: 0.0356828	total: 31.4s	remaining: 9.82s
# 457:	learn: 0.0356056	total: 31.5s	remaining: 9.75s
# 458:	learn: 0.0355559	total: 31.5s	remaining: 9.68s
# 459:	learn: 0.0355422	total: 31.6s	remaining: 9.61s
# 460:	learn: 0.0355332	total: 31.6s	remaining: 9.54s
# 461:	learn: 0.0354577	total: 31.7s	remaining: 9.47s
# 462:	learn: 0.0354363	total: 31.8s	remaining: 9.4s
# 463:	learn: 0.0354185	total: 31.8s	remaining: 9.33s
# 464:	learn: 0.0353402	total: 31.9s	remaining: 9.27s
# 465:	learn: 0.0352932	total: 32s	remaining: 9.2s
# 466:	learn: 0.0352658	total: 32s	remaining: 9.13s
# 467:	learn: 0.0352260	total: 32.1s	remaining: 9.06s
# 468:	learn: 0.0351714	total: 32.2s	remaining: 8.99s
# 469:	learn: 0.0350304	total: 32.3s	remaining: 8.92s
# 470:	learn: 0.0349814	total: 32.3s	remaining: 8.85s
# 471:	learn: 0.0349158	total: 32.4s	remaining: 8.78s
# 472:	learn: 0.0348813	total: 32.5s	remaining: 8.71s
# 473:	learn: 0.0348640	total: 32.5s	remaining: 8.64s
# 474:	learn: 0.0347970	total: 32.6s	remaining: 8.57s
# 475:	learn: 0.0347715	total: 32.7s	remaining: 8.51s
# 476:	learn: 0.0347346	total: 32.7s	remaining: 8.44s
# 477:	learn: 0.0346799	total: 32.8s	remaining: 8.37s
# 478:	learn: 0.0346488	total: 32.8s	remaining: 8.3s
# 479:	learn: 0.0345772	total: 32.9s	remaining: 8.23s
# 480:	learn: 0.0345478	total: 33s	remaining: 8.16s
# 481:	learn: 0.0345047	total: 33s	remaining: 8.09s
# 482:	learn: 0.0343308	total: 33.1s	remaining: 8.02s
# 483:	learn: 0.0343200	total: 33.2s	remaining: 7.95s
# 484:	learn: 0.0342926	total: 33.2s	remaining: 7.88s
# 485:	learn: 0.0342886	total: 33.3s	remaining: 7.81s
# 486:	learn: 0.0341955	total: 33.4s	remaining: 7.75s
# 487:	learn: 0.0341433	total: 33.4s	remaining: 7.68s
# 488:	learn: 0.0341023	total: 33.5s	remaining: 7.61s
# 489:	learn: 0.0340381	total: 33.6s	remaining: 7.54s
# 490:	learn: 0.0339409	total: 33.6s	remaining: 7.47s
# 491:	learn: 0.0338767	total: 33.7s	remaining: 7.4s
# 492:	learn: 0.0337832	total: 33.8s	remaining: 7.34s
# 493:	learn: 0.0337453	total: 33.9s	remaining: 7.27s
# 494:	learn: 0.0336561	total: 33.9s	remaining: 7.2s
# 495:	learn: 0.0336223	total: 34s	remaining: 7.13s
# 496:	learn: 0.0336148	total: 34.1s	remaining: 7.06s
# 497:	learn: 0.0335466	total: 34.1s	remaining: 6.99s
# 498:	learn: 0.0334638	total: 34.2s	remaining: 6.92s
# 499:	learn: 0.0334422	total: 34.3s	remaining: 6.85s
# 500:	learn: 0.0333722	total: 34.3s	remaining: 6.78s
# 501:	learn: 0.0333315	total: 34.4s	remaining: 6.71s
# 502:	learn: 0.0332483	total: 34.5s	remaining: 6.65s
# 503:	learn: 0.0332152	total: 34.5s	remaining: 6.58s
# 504:	learn: 0.0331499	total: 34.6s	remaining: 6.51s
# 505:	learn: 0.0331073	total: 34.7s	remaining: 6.44s
# 506:	learn: 0.0329826	total: 34.7s	remaining: 6.37s
# 507:	learn: 0.0329299	total: 34.8s	remaining: 6.3s
# 508:	learn: 0.0329109	total: 34.9s	remaining: 6.23s
# 509:	learn: 0.0328812	total: 34.9s	remaining: 6.17s
# 510:	learn: 0.0328473	total: 35s	remaining: 6.1s
# 511:	learn: 0.0327717	total: 35.1s	remaining: 6.03s
# 512:	learn: 0.0326634	total: 35.2s	remaining: 5.96s
# 513:	learn: 0.0326349	total: 35.2s	remaining: 5.89s
# 514:	learn: 0.0326196	total: 35.3s	remaining: 5.82s
# 515:	learn: 0.0325395	total: 35.3s	remaining: 5.75s
# 516:	learn: 0.0325094	total: 35.4s	remaining: 5.68s
# 517:	learn: 0.0324648	total: 35.5s	remaining: 5.62s
# 518:	learn: 0.0323957	total: 35.5s	remaining: 5.55s
# 519:	learn: 0.0323281	total: 35.6s	remaining: 5.48s
# 520:	learn: 0.0322909	total: 35.7s	remaining: 5.41s
# 521:	learn: 0.0322354	total: 35.7s	remaining: 5.34s
# 522:	learn: 0.0321549	total: 35.8s	remaining: 5.27s
# 523:	learn: 0.0321272	total: 35.9s	remaining: 5.2s
# 524:	learn: 0.0320785	total: 35.9s	remaining: 5.13s
# 525:	learn: 0.0320070	total: 36s	remaining: 5.07s
# 526:	learn: 0.0319638	total: 36.1s	remaining: 5s
# 527:	learn: 0.0319448	total: 36.1s	remaining: 4.93s
# 528:	learn: 0.0319091	total: 36.2s	remaining: 4.86s
# 529:	learn: 0.0318265	total: 36.3s	remaining: 4.79s
# 530:	learn: 0.0317287	total: 36.3s	remaining: 4.72s
# 531:	learn: 0.0317072	total: 36.4s	remaining: 4.65s
# 532:	learn: 0.0316247	total: 36.5s	remaining: 4.59s
# 533:	learn: 0.0315552	total: 36.6s	remaining: 4.52s
# 534:	learn: 0.0315123	total: 36.6s	remaining: 4.45s
# 535:	learn: 0.0314550	total: 36.7s	remaining: 4.38s
# 536:	learn: 0.0313743	total: 36.8s	remaining: 4.31s
# 537:	learn: 0.0313159	total: 36.8s	remaining: 4.24s
# 538:	learn: 0.0312265	total: 36.9s	remaining: 4.17s
# 539:	learn: 0.0311388	total: 37s	remaining: 4.11s
# 540:	learn: 0.0310096	total: 37s	remaining: 4.04s
# 541:	learn: 0.0309871	total: 37.1s	remaining: 3.97s
# 542:	learn: 0.0309026	total: 37.2s	remaining: 3.9s
# 543:	learn: 0.0308586	total: 37.2s	remaining: 3.83s
# 544:	learn: 0.0308115	total: 37.3s	remaining: 3.77s
# 545:	learn: 0.0307925	total: 37.4s	remaining: 3.7s
# 546:	learn: 0.0307585	total: 37.4s	remaining: 3.63s
# 547:	learn: 0.0307199	total: 37.5s	remaining: 3.56s
# 548:	learn: 0.0306806	total: 37.6s	remaining: 3.49s
# 549:	learn: 0.0306585	total: 37.6s	remaining: 3.42s
# 550:	learn: 0.0306409	total: 37.7s	remaining: 3.35s
# 551:	learn: 0.0306136	total: 37.8s	remaining: 3.28s
# 552:	learn: 0.0305760	total: 37.8s	remaining: 3.22s
# 553:	learn: 0.0305064	total: 37.9s	remaining: 3.15s
# 554:	learn: 0.0304505	total: 38s	remaining: 3.08s
# 555:	learn: 0.0304229	total: 38s	remaining: 3.01s
# 556:	learn: 0.0303616	total: 38.1s	remaining: 2.94s
# 557:	learn: 0.0303471	total: 38.2s	remaining: 2.87s
# 558:	learn: 0.0303275	total: 38.2s	remaining: 2.8s
# 559:	learn: 0.0303139	total: 38.3s	remaining: 2.73s
# 560:	learn: 0.0302695	total: 38.4s	remaining: 2.67s
# 561:	learn: 0.0302236	total: 38.4s	remaining: 2.6s
# 562:	learn: 0.0301979	total: 38.5s	remaining: 2.53s
# 563:	learn: 0.0301727	total: 38.6s	remaining: 2.46s
# 564:	learn: 0.0301411	total: 38.6s	remaining: 2.39s
# 565:	learn: 0.0300927	total: 38.7s	remaining: 2.32s
# 566:	learn: 0.0300104	total: 38.8s	remaining: 2.26s
# 567:	learn: 0.0299762	total: 38.8s	remaining: 2.19s
# 568:	learn: 0.0299251	total: 38.9s	remaining: 2.12s
# 569:	learn: 0.0298749	total: 39s	remaining: 2.05s
# 570:	learn: 0.0298456	total: 39s	remaining: 1.98s
# 571:	learn: 0.0298060	total: 39.1s	remaining: 1.91s
# 572:	learn: 0.0297800	total: 39.2s	remaining: 1.84s
# 573:	learn: 0.0297211	total: 39.2s	remaining: 1.78s
# 574:	learn: 0.0296691	total: 39.3s	remaining: 1.71s
# 575:	learn: 0.0296618	total: 39.4s	remaining: 1.64s
# 576:	learn: 0.0296485	total: 39.4s	remaining: 1.57s
# 577:	learn: 0.0296341	total: 39.5s	remaining: 1.5s
# 578:	learn: 0.0295800	total: 39.6s	remaining: 1.44s
# 579:	learn: 0.0295117	total: 39.6s	remaining: 1.37s
# 580:	learn: 0.0294448	total: 39.7s	remaining: 1.3s
# 581:	learn: 0.0294331	total: 39.8s	remaining: 1.23s
# 582:	learn: 0.0293553	total: 39.8s	remaining: 1.16s
# 583:	learn: 0.0293241	total: 39.9s	remaining: 1.09s
# 584:	learn: 0.0293021	total: 40s	remaining: 1.02s
# 585:	learn: 0.0292174	total: 40s	remaining: 956ms
# 586:	learn: 0.0291844	total: 40.1s	remaining: 888ms
# 587:	learn: 0.0291512	total: 40.2s	remaining: 820ms
# 588:	learn: 0.0291159	total: 40.2s	remaining: 751ms
# 589:	learn: 0.0290998	total: 40.3s	remaining: 683ms
# 590:	learn: 0.0290536	total: 40.4s	remaining: 615ms
# 591:	learn: 0.0290333	total: 40.4s	remaining: 546ms
# 592:	learn: 0.0290133	total: 40.5s	remaining: 478ms
# 593:	learn: 0.0289854	total: 40.6s	remaining: 410ms
# 594:	learn: 0.0289598	total: 40.6s	remaining: 341ms
# 595:	learn: 0.0289494	total: 40.7s	remaining: 273ms
# 596:	learn: 0.0288827	total: 40.8s	remaining: 205ms
# 597:	learn: 0.0287757	total: 40.8s	remaining: 137ms
# 598:	learn: 0.0287310	total: 40.9s	remaining: 68.3ms
# 599:	learn: 0.0286730	total: 41s	remaining: 0us
# 第  1  折交叉验证 :  accuracy ：  0.9807857142857143
# 第  2  折交叉验证开始...
# 0:	learn: 1.0698930	total: 81.7ms	remaining: 48.9s
# 1:	learn: 0.8832645	total: 159ms	remaining: 47.4s
# 2:	learn: 0.7514466	total: 239ms	remaining: 47.5s
# 3:	learn: 0.6516996	total: 315ms	remaining: 46.9s
# 4:	learn: 0.5729999	total: 395ms	remaining: 47.1s
# 5:	learn: 0.5123070	total: 475ms	remaining: 47s
# 6:	learn: 0.4622995	total: 557ms	remaining: 47.2s
# 7:	learn: 0.4185020	total: 637ms	remaining: 47.1s
# 8:	learn: 0.3840850	total: 714ms	remaining: 46.9s
# 9:	learn: 0.3524879	total: 798ms	remaining: 47.1s
# 10:	learn: 0.3276887	total: 881ms	remaining: 47.2s
# 11:	learn: 0.3073253	total: 958ms	remaining: 47s
# 12:	learn: 0.2885270	total: 1.04s	remaining: 46.9s
# 13:	learn: 0.2714335	total: 1.12s	remaining: 46.8s
# 14:	learn: 0.2570091	total: 1.2s	remaining: 46.7s
# 15:	learn: 0.2457002	total: 1.27s	remaining: 46.5s
# 16:	learn: 0.2327895	total: 1.35s	remaining: 46.5s
# 17:	learn: 0.2210240	total: 1.44s	remaining: 46.5s
# 18:	learn: 0.2125303	total: 1.51s	remaining: 46.3s
# 19:	learn: 0.2039283	total: 1.59s	remaining: 46.2s
# 20:	learn: 0.1966031	total: 1.68s	remaining: 46.4s
# 21:	learn: 0.1897614	total: 1.76s	remaining: 46.2s
# 22:	learn: 0.1841860	total: 1.85s	remaining: 46.5s
# 23:	learn: 0.1790192	total: 1.93s	remaining: 46.4s
# 24:	learn: 0.1741443	total: 2.01s	remaining: 46.2s
# 25:	learn: 0.1703590	total: 2.08s	remaining: 46s
# 26:	learn: 0.1663186	total: 2.17s	remaining: 46s
# 27:	learn: 0.1616239	total: 2.25s	remaining: 45.9s
# 28:	learn: 0.1585913	total: 2.32s	remaining: 45.8s
# 29:	learn: 0.1543950	total: 2.4s	remaining: 45.6s
# 30:	learn: 0.1506279	total: 2.47s	remaining: 45.4s
# 31:	learn: 0.1467335	total: 2.56s	remaining: 45.4s
# 32:	learn: 0.1435559	total: 2.63s	remaining: 45.2s
# 33:	learn: 0.1411477	total: 2.7s	remaining: 45s
# 34:	learn: 0.1388416	total: 2.77s	remaining: 44.7s
# 35:	learn: 0.1365001	total: 2.84s	remaining: 44.5s
# 36:	learn: 0.1337719	total: 2.92s	remaining: 44.4s
# 37:	learn: 0.1315978	total: 3s	remaining: 44.4s
# 38:	learn: 0.1299160	total: 3.07s	remaining: 44.2s
# 39:	learn: 0.1275932	total: 3.15s	remaining: 44.1s
# 40:	learn: 0.1255662	total: 3.24s	remaining: 44.2s
# 41:	learn: 0.1239747	total: 3.31s	remaining: 44s
# 42:	learn: 0.1222592	total: 3.39s	remaining: 43.9s
# 43:	learn: 0.1207329	total: 3.46s	remaining: 43.7s
# 44:	learn: 0.1185052	total: 3.54s	remaining: 43.7s
# 45:	learn: 0.1165551	total: 3.62s	remaining: 43.6s
# 46:	learn: 0.1151235	total: 3.69s	remaining: 43.4s
# 47:	learn: 0.1136240	total: 3.78s	remaining: 43.4s
# 48:	learn: 0.1129724	total: 3.85s	remaining: 43.2s
# 49:	learn: 0.1121423	total: 3.91s	remaining: 43s
# 50:	learn: 0.1108807	total: 3.99s	remaining: 42.9s
# 51:	learn: 0.1100805	total: 4.06s	remaining: 42.8s
# 52:	learn: 0.1084145	total: 4.13s	remaining: 42.7s
# 53:	learn: 0.1078051	total: 4.2s	remaining: 42.5s
# 54:	learn: 0.1065539	total: 4.28s	remaining: 42.4s
# 55:	learn: 0.1061336	total: 4.35s	remaining: 42.3s
# 56:	learn: 0.1051663	total: 4.42s	remaining: 42.1s
# 57:	learn: 0.1040735	total: 4.5s	remaining: 42s
# 58:	learn: 0.1031879	total: 4.58s	remaining: 42s
# 59:	learn: 0.1019734	total: 4.66s	remaining: 41.9s
# 60:	learn: 0.1010874	total: 4.72s	remaining: 41.7s
# 61:	learn: 0.1006786	total: 4.8s	remaining: 41.7s
# 62:	learn: 0.1000217	total: 4.87s	remaining: 41.5s
# 63:	learn: 0.0995063	total: 4.94s	remaining: 41.3s
# 64:	learn: 0.0990562	total: 5.01s	remaining: 41.2s
# 65:	learn: 0.0978878	total: 5.09s	remaining: 41.1s
# 66:	learn: 0.0970146	total: 5.16s	remaining: 41.1s
# 67:	learn: 0.0962046	total: 5.24s	remaining: 41s
# 68:	learn: 0.0952929	total: 5.3s	remaining: 40.8s
# 69:	learn: 0.0948462	total: 5.37s	remaining: 40.7s
# 70:	learn: 0.0938346	total: 5.45s	remaining: 40.6s
# 71:	learn: 0.0931548	total: 5.53s	remaining: 40.5s
# 72:	learn: 0.0923765	total: 5.6s	remaining: 40.4s
# 73:	learn: 0.0915513	total: 5.68s	remaining: 40.4s
# 74:	learn: 0.0907470	total: 5.75s	remaining: 40.2s
# 75:	learn: 0.0903291	total: 5.81s	remaining: 40.1s
# 76:	learn: 0.0899436	total: 5.88s	remaining: 39.9s
# 77:	learn: 0.0889562	total: 5.96s	remaining: 39.9s
# 78:	learn: 0.0883547	total: 6.03s	remaining: 39.8s
# 79:	learn: 0.0874885	total: 6.11s	remaining: 39.7s
# 80:	learn: 0.0868009	total: 6.18s	remaining: 39.6s
# 81:	learn: 0.0861132	total: 6.26s	remaining: 39.5s
# 82:	learn: 0.0854251	total: 6.34s	remaining: 39.5s
# 83:	learn: 0.0847624	total: 6.41s	remaining: 39.4s
# 84:	learn: 0.0845022	total: 6.48s	remaining: 39.3s
# 85:	learn: 0.0840085	total: 6.55s	remaining: 39.2s
# 86:	learn: 0.0837059	total: 6.62s	remaining: 39s
# 87:	learn: 0.0830717	total: 6.7s	remaining: 39s
# 88:	learn: 0.0826885	total: 6.77s	remaining: 38.9s
# 89:	learn: 0.0825450	total: 6.83s	remaining: 38.7s
# 90:	learn: 0.0820200	total: 6.91s	remaining: 38.6s
# 91:	learn: 0.0815276	total: 6.98s	remaining: 38.5s
# 92:	learn: 0.0813701	total: 7.04s	remaining: 38.4s
# 93:	learn: 0.0810966	total: 7.11s	remaining: 38.3s
# 94:	learn: 0.0808818	total: 7.17s	remaining: 38.1s
# 95:	learn: 0.0803990	total: 7.25s	remaining: 38s
# 96:	learn: 0.0800582	total: 7.31s	remaining: 37.9s
# 97:	learn: 0.0797501	total: 7.38s	remaining: 37.8s
# 98:	learn: 0.0794229	total: 7.45s	remaining: 37.7s
# 99:	learn: 0.0793318	total: 7.51s	remaining: 37.5s
# 100:	learn: 0.0789249	total: 7.58s	remaining: 37.4s
# 101:	learn: 0.0786865	total: 7.65s	remaining: 37.3s
# 102:	learn: 0.0782844	total: 7.71s	remaining: 37.2s
# 103:	learn: 0.0780458	total: 7.78s	remaining: 37.1s
# 104:	learn: 0.0777146	total: 7.85s	remaining: 37s
# 105:	learn: 0.0772429	total: 7.92s	remaining: 36.9s
# 106:	learn: 0.0767723	total: 7.99s	remaining: 36.8s
# 107:	learn: 0.0764858	total: 8.06s	remaining: 36.7s
# 108:	learn: 0.0763388	total: 8.12s	remaining: 36.6s
# 109:	learn: 0.0761426	total: 8.18s	remaining: 36.5s
# 110:	learn: 0.0756492	total: 8.26s	remaining: 36.4s
# 111:	learn: 0.0756082	total: 8.32s	remaining: 36.2s
# 112:	learn: 0.0751528	total: 8.38s	remaining: 36.1s
# 113:	learn: 0.0747734	total: 8.44s	remaining: 36s
# 114:	learn: 0.0743632	total: 8.51s	remaining: 35.9s
# 115:	learn: 0.0739280	total: 8.59s	remaining: 35.8s
# 116:	learn: 0.0735535	total: 8.67s	remaining: 35.8s
# 117:	learn: 0.0734471	total: 8.73s	remaining: 35.7s
# 118:	learn: 0.0731420	total: 8.8s	remaining: 35.6s
# 119:	learn: 0.0727794	total: 8.87s	remaining: 35.5s
# 120:	learn: 0.0724213	total: 8.95s	remaining: 35.4s
# 121:	learn: 0.0722535	total: 9.01s	remaining: 35.3s
# 122:	learn: 0.0721180	total: 9.07s	remaining: 35.2s
# 123:	learn: 0.0719094	total: 9.14s	remaining: 35.1s
# 124:	learn: 0.0717799	total: 9.21s	remaining: 35s
# 125:	learn: 0.0713811	total: 9.29s	remaining: 34.9s
# 126:	learn: 0.0711125	total: 9.35s	remaining: 34.8s
# 127:	learn: 0.0707862	total: 9.42s	remaining: 34.7s
# 128:	learn: 0.0706296	total: 9.48s	remaining: 34.6s
# 129:	learn: 0.0703746	total: 9.55s	remaining: 34.5s
# 130:	learn: 0.0699945	total: 9.62s	remaining: 34.4s
# 131:	learn: 0.0695658	total: 9.69s	remaining: 34.4s
# 132:	learn: 0.0691529	total: 9.76s	remaining: 34.3s
# 133:	learn: 0.0688680	total: 9.83s	remaining: 34.2s
# 134:	learn: 0.0684689	total: 9.9s	remaining: 34.1s
# 135:	learn: 0.0682416	total: 9.97s	remaining: 34s
# 136:	learn: 0.0680385	total: 10s	remaining: 33.9s
# 137:	learn: 0.0678184	total: 10.1s	remaining: 33.8s
# 138:	learn: 0.0675177	total: 10.2s	remaining: 33.8s
# 139:	learn: 0.0670140	total: 10.3s	remaining: 33.7s
# 140:	learn: 0.0667792	total: 10.3s	remaining: 33.6s
# 141:	learn: 0.0666272	total: 10.4s	remaining: 33.5s
# 142:	learn: 0.0664470	total: 10.5s	remaining: 33.4s
# 143:	learn: 0.0661849	total: 10.5s	remaining: 33.3s
# 144:	learn: 0.0658841	total: 10.6s	remaining: 33.3s
# 145:	learn: 0.0656560	total: 10.7s	remaining: 33.2s
# 146:	learn: 0.0653980	total: 10.7s	remaining: 33.1s
# 147:	learn: 0.0651804	total: 10.8s	remaining: 33s
# 148:	learn: 0.0650686	total: 10.9s	remaining: 33s
# 149:	learn: 0.0646499	total: 11s	remaining: 32.9s
# 150:	learn: 0.0645711	total: 11s	remaining: 32.8s
# 151:	learn: 0.0641648	total: 11.1s	remaining: 32.7s
# 152:	learn: 0.0638837	total: 11.2s	remaining: 32.6s
# 153:	learn: 0.0638032	total: 11.2s	remaining: 32.5s
# 154:	learn: 0.0635201	total: 11.3s	remaining: 32.5s
# 155:	learn: 0.0631217	total: 11.4s	remaining: 32.4s
# 156:	learn: 0.0629040	total: 11.5s	remaining: 32.3s
# 157:	learn: 0.0628052	total: 11.5s	remaining: 32.2s
# 158:	learn: 0.0626165	total: 11.6s	remaining: 32.1s
# 159:	learn: 0.0622978	total: 11.7s	remaining: 32.1s
# 160:	learn: 0.0622596	total: 11.7s	remaining: 32s
# 161:	learn: 0.0621261	total: 11.8s	remaining: 31.9s
# 162:	learn: 0.0620470	total: 11.9s	remaining: 31.8s
# 163:	learn: 0.0619246	total: 11.9s	remaining: 31.7s
# 164:	learn: 0.0618027	total: 12s	remaining: 31.6s
# 165:	learn: 0.0616338	total: 12.1s	remaining: 31.5s
# 166:	learn: 0.0613980	total: 12.1s	remaining: 31.5s
# 167:	learn: 0.0611123	total: 12.2s	remaining: 31.4s
# 168:	learn: 0.0608257	total: 12.3s	remaining: 31.3s
# 169:	learn: 0.0605062	total: 12.4s	remaining: 31.3s
# 170:	learn: 0.0604225	total: 12.4s	remaining: 31.2s
# 171:	learn: 0.0603368	total: 12.5s	remaining: 31.1s
# 172:	learn: 0.0599156	total: 12.6s	remaining: 31s
# 173:	learn: 0.0597710	total: 12.6s	remaining: 30.9s
# 174:	learn: 0.0593648	total: 12.7s	remaining: 30.9s
# 175:	learn: 0.0591358	total: 12.8s	remaining: 30.8s
# 176:	learn: 0.0589765	total: 12.9s	remaining: 30.7s
# 177:	learn: 0.0587274	total: 12.9s	remaining: 30.6s
# 178:	learn: 0.0584377	total: 13s	remaining: 30.6s
# 179:	learn: 0.0582596	total: 13.1s	remaining: 30.5s
# 180:	learn: 0.0581739	total: 13.1s	remaining: 30.4s
# 181:	learn: 0.0580127	total: 13.2s	remaining: 30.3s
# 182:	learn: 0.0578714	total: 13.3s	remaining: 30.2s
# 183:	learn: 0.0575453	total: 13.3s	remaining: 30.2s
# 184:	learn: 0.0573937	total: 13.4s	remaining: 30.1s
# 185:	learn: 0.0572622	total: 13.5s	remaining: 30s
# 186:	learn: 0.0571758	total: 13.6s	remaining: 29.9s
# 187:	learn: 0.0569652	total: 13.6s	remaining: 29.9s
# 188:	learn: 0.0568116	total: 13.7s	remaining: 29.8s
# 189:	learn: 0.0567432	total: 13.8s	remaining: 29.7s
# 190:	learn: 0.0565310	total: 13.8s	remaining: 29.6s
# 191:	learn: 0.0564705	total: 13.9s	remaining: 29.5s
# 192:	learn: 0.0563678	total: 13.9s	remaining: 29.4s
# 193:	learn: 0.0562329	total: 14s	remaining: 29.3s
# 194:	learn: 0.0560965	total: 14.1s	remaining: 29.2s
# 195:	learn: 0.0560313	total: 14.1s	remaining: 29.1s
# 196:	learn: 0.0559700	total: 14.2s	remaining: 29.1s
# 197:	learn: 0.0558690	total: 14.3s	remaining: 29s
# 198:	learn: 0.0555276	total: 14.4s	remaining: 28.9s
# 199:	learn: 0.0553916	total: 14.4s	remaining: 28.8s
# 200:	learn: 0.0552708	total: 14.5s	remaining: 28.8s
# 201:	learn: 0.0552079	total: 14.5s	remaining: 28.7s
# 202:	learn: 0.0550264	total: 14.6s	remaining: 28.6s
# 203:	learn: 0.0548100	total: 14.7s	remaining: 28.5s
# 204:	learn: 0.0545859	total: 14.8s	remaining: 28.5s
# 205:	learn: 0.0544171	total: 14.8s	remaining: 28.4s
# 206:	learn: 0.0543449	total: 14.9s	remaining: 28.3s
# 207:	learn: 0.0542335	total: 15s	remaining: 28.2s
# 208:	learn: 0.0540333	total: 15s	remaining: 28.1s
# 209:	learn: 0.0538632	total: 15.1s	remaining: 28s
# 210:	learn: 0.0537322	total: 15.2s	remaining: 28s
# 211:	learn: 0.0536824	total: 15.2s	remaining: 27.9s
# 212:	learn: 0.0536335	total: 15.3s	remaining: 27.8s
# 213:	learn: 0.0535012	total: 15.4s	remaining: 27.7s
# 214:	learn: 0.0533595	total: 15.4s	remaining: 27.6s
# 215:	learn: 0.0531808	total: 15.5s	remaining: 27.6s
# 216:	learn: 0.0529178	total: 15.6s	remaining: 27.5s
# 217:	learn: 0.0527103	total: 15.7s	remaining: 27.4s
# 218:	learn: 0.0525748	total: 15.7s	remaining: 27.3s
# 219:	learn: 0.0525055	total: 15.8s	remaining: 27.3s
# 220:	learn: 0.0522981	total: 15.9s	remaining: 27.2s
# 221:	learn: 0.0522579	total: 15.9s	remaining: 27.1s
# 222:	learn: 0.0521993	total: 16s	remaining: 27s
# 223:	learn: 0.0520037	total: 16.1s	remaining: 27s
# 224:	learn: 0.0516911	total: 16.1s	remaining: 26.9s
# 225:	learn: 0.0516048	total: 16.2s	remaining: 26.8s
# 226:	learn: 0.0514771	total: 16.3s	remaining: 26.7s
# 227:	learn: 0.0514064	total: 16.3s	remaining: 26.6s
# 228:	learn: 0.0513763	total: 16.4s	remaining: 26.6s
# 229:	learn: 0.0513048	total: 16.5s	remaining: 26.5s
# 230:	learn: 0.0511198	total: 16.5s	remaining: 26.4s
# 231:	learn: 0.0511134	total: 16.6s	remaining: 26.3s
# 232:	learn: 0.0510259	total: 16.6s	remaining: 26.2s
# 233:	learn: 0.0508819	total: 16.7s	remaining: 26.1s
# 234:	learn: 0.0508542	total: 16.8s	remaining: 26.1s
# 235:	learn: 0.0506238	total: 16.8s	remaining: 26s
# 236:	learn: 0.0505656	total: 16.9s	remaining: 25.9s
# 237:	learn: 0.0504084	total: 17s	remaining: 25.8s
# 238:	learn: 0.0502658	total: 17s	remaining: 25.8s
# 239:	learn: 0.0501483	total: 17.1s	remaining: 25.7s
# 240:	learn: 0.0500509	total: 17.2s	remaining: 25.6s
# 241:	learn: 0.0499946	total: 17.2s	remaining: 25.5s
# 242:	learn: 0.0498434	total: 17.3s	remaining: 25.4s
# 243:	learn: 0.0497753	total: 17.4s	remaining: 25.4s
# 244:	learn: 0.0496664	total: 17.4s	remaining: 25.3s
# 245:	learn: 0.0494258	total: 17.5s	remaining: 25.2s
# 246:	learn: 0.0493746	total: 17.6s	remaining: 25.1s
# 247:	learn: 0.0492379	total: 17.7s	remaining: 25.1s
# 248:	learn: 0.0491962	total: 17.7s	remaining: 25s
# 249:	learn: 0.0491006	total: 17.8s	remaining: 24.9s
# 250:	learn: 0.0490678	total: 17.8s	remaining: 24.8s
# 251:	learn: 0.0490142	total: 17.9s	remaining: 24.7s
# 252:	learn: 0.0488848	total: 18s	remaining: 24.7s
# 253:	learn: 0.0487021	total: 18.1s	remaining: 24.6s
# 254:	learn: 0.0486303	total: 18.1s	remaining: 24.5s
# 255:	learn: 0.0485379	total: 18.2s	remaining: 24.4s
# 256:	learn: 0.0484757	total: 18.2s	remaining: 24.4s
# 257:	learn: 0.0484225	total: 18.3s	remaining: 24.3s
# 258:	learn: 0.0483263	total: 18.4s	remaining: 24.2s
# 259:	learn: 0.0482672	total: 18.4s	remaining: 24.1s
# 260:	learn: 0.0481157	total: 18.5s	remaining: 24s
# 261:	learn: 0.0479722	total: 18.6s	remaining: 24s
# 262:	learn: 0.0477898	total: 18.7s	remaining: 23.9s
# 263:	learn: 0.0477071	total: 18.7s	remaining: 23.8s
# 264:	learn: 0.0476306	total: 18.8s	remaining: 23.8s
# 265:	learn: 0.0475767	total: 18.9s	remaining: 23.7s
# ...
# 299:	learn: 0.0464309	total: 20.9s	remaining: 20.9s
# 300:	learn: 0.0462092	total: 21s	remaining: 20.8s
# 301:	learn: 0.0460834	total: 21s	remaining: 20.7s
# 302:	learn: 0.0460468	total: 21.1s	remaining: 20.7s
# 303:	learn: 0.0458804	total: 21.2s	remaining: 20.6s
# 304:	learn: 0.0458316	total: 21.2s	remaining: 20.5s
# 305:	learn: 0.0456542	total: 21.3s	remaining: 20.5s
# 306:	learn: 0.0456222	total: 21.4s	remaining: 20.4s
# 307:	learn: 0.0455237	total: 21.4s	remaining: 20.3s
# 308:	learn: 0.0454988	total: 21.5s	remaining: 20.2s
# 309:	learn: 0.0454620	total: 21.6s	remaining: 20.2s
# 310:	learn: 0.0453107	total: 21.6s	remaining: 20.1s
# 311:	learn: 0.0452859	total: 21.7s	remaining: 20s
# 312:	learn: 0.0451862	total: 21.8s	remaining: 20s
# 313:	learn: 0.0451467	total: 21.8s	remaining: 19.9s
# 314:	learn: 0.0450812	total: 21.9s	remaining: 19.8s
# 315:	learn: 0.0449677	total: 22s	remaining: 19.7s
# 316:	learn: 0.0449591	total: 22s	remaining: 19.7s
# 317:	learn: 0.0449134	total: 22.1s	remaining: 19.6s
# 318:	learn: 0.0447162	total: 22.2s	remaining: 19.5s
# 319:	learn: 0.0445729	total: 22.2s	remaining: 19.5s
# 320:	learn: 0.0445643	total: 22.3s	remaining: 19.4s
# 321:	learn: 0.0445504	total: 22.3s	remaining: 19.3s
# 322:	learn: 0.0444356	total: 22.4s	remaining: 19.2s
# 323:	learn: 0.0444242	total: 22.5s	remaining: 19.1s
# 324:	learn: 0.0443732	total: 22.5s	remaining: 19.1s
# 325:	learn: 0.0443127	total: 22.6s	remaining: 19s
# 326:	learn: 0.0441838	total: 22.7s	remaining: 18.9s
# 327:	learn: 0.0440224	total: 22.7s	remaining: 18.9s
# 328:	learn: 0.0438624	total: 22.8s	remaining: 18.8s
# 329:	learn: 0.0437963	total: 22.9s	remaining: 18.7s
# 330:	learn: 0.0437495	total: 22.9s	remaining: 18.6s
# 331:	learn: 0.0436000	total: 23s	remaining: 18.6s
# 332:	learn: 0.0435322	total: 23.1s	remaining: 18.5s
# 333:	learn: 0.0433957	total: 23.2s	remaining: 18.4s
# 334:	learn: 0.0433780	total: 23.2s	remaining: 18.4s
# 335:	learn: 0.0433385	total: 23.3s	remaining: 18.3s
# 336:	learn: 0.0433148	total: 23.3s	remaining: 18.2s
# 337:	learn: 0.0432726	total: 23.4s	remaining: 18.1s
# 338:	learn: 0.0431658	total: 23.5s	remaining: 18.1s
# 339:	learn: 0.0431448	total: 23.5s	remaining: 18s
# 340:	learn: 0.0430891	total: 23.6s	remaining: 17.9s
# 341:	learn: 0.0430688	total: 23.7s	remaining: 17.9s
# 342:	learn: 0.0429521	total: 23.7s	remaining: 17.8s
# 343:	learn: 0.0429300	total: 23.8s	remaining: 17.7s
# 344:	learn: 0.0428294	total: 23.9s	remaining: 17.6s
# 345:	learn: 0.0427864	total: 23.9s	remaining: 17.6s
# 346:	learn: 0.0427753	total: 24s	remaining: 17.5s
# 347:	learn: 0.0427088	total: 24.1s	remaining: 17.4s
# 348:	learn: 0.0426362	total: 24.1s	remaining: 17.4s
# 349:	learn: 0.0424869	total: 24.2s	remaining: 17.3s
# 350:	learn: 0.0424359	total: 24.3s	remaining: 17.2s
# 351:	learn: 0.0424281	total: 24.3s	remaining: 17.1s
# 352:	learn: 0.0423484	total: 24.4s	remaining: 17.1s
# 353:	learn: 0.0423405	total: 24.4s	remaining: 17s
# 354:	learn: 0.0423050	total: 24.5s	remaining: 16.9s
# 355:	learn: 0.0422114	total: 24.6s	remaining: 16.8s
# 356:	learn: 0.0421527	total: 24.6s	remaining: 16.8s
# 357:	learn: 0.0420771	total: 24.7s	remaining: 16.7s
# 358:	learn: 0.0419911	total: 24.8s	remaining: 16.6s
# 359:	learn: 0.0418775	total: 24.8s	remaining: 16.6s
# 360:	learn: 0.0418422	total: 24.9s	remaining: 16.5s
# 361:	learn: 0.0418378	total: 25s	remaining: 16.4s
# 362:	learn: 0.0417814	total: 25s	remaining: 16.3s
# 363:	learn: 0.0416638	total: 25.1s	remaining: 16.3s
# 364:	learn: 0.0415874	total: 25.2s	remaining: 16.2s
# 365:	learn: 0.0414870	total: 25.2s	remaining: 16.1s
# 366:	learn: 0.0414609	total: 25.3s	remaining: 16.1s
# 367:	learn: 0.0414019	total: 25.4s	remaining: 16s
# 368:	learn: 0.0413582	total: 25.4s	remaining: 15.9s
# 369:	learn: 0.0412368	total: 25.5s	remaining: 15.9s
# 370:	learn: 0.0411705	total: 25.6s	remaining: 15.8s
# 371:	learn: 0.0411341	total: 25.6s	remaining: 15.7s
# 372:	learn: 0.0410389	total: 25.7s	remaining: 15.6s
# 373:	learn: 0.0409416	total: 25.8s	remaining: 15.6s
# 374:	learn: 0.0408177	total: 25.8s	remaining: 15.5s
# 375:	learn: 0.0407441	total: 25.9s	remaining: 15.4s
# 376:	learn: 0.0406163	total: 26s	remaining: 15.4s
# 377:	learn: 0.0405550	total: 26.1s	remaining: 15.3s
# 378:	learn: 0.0405343	total: 26.1s	remaining: 15.2s
# 379:	learn: 0.0405017	total: 26.2s	remaining: 15.2s
# 380:	learn: 0.0404834	total: 26.2s	remaining: 15.1s
# 381:	learn: 0.0404449	total: 26.3s	remaining: 15s
# 382:	learn: 0.0403472	total: 26.4s	remaining: 14.9s
# 383:	learn: 0.0402924	total: 26.4s	remaining: 14.9s
# 384:	learn: 0.0402594	total: 26.5s	remaining: 14.8s
# 385:	learn: 0.0402335	total: 26.6s	remaining: 14.7s
# 386:	learn: 0.0402022	total: 26.6s	remaining: 14.7s
# 387:	learn: 0.0400311	total: 26.7s	remaining: 14.6s
# 388:	learn: 0.0399547	total: 26.8s	remaining: 14.5s
# 389:	learn: 0.0398961	total: 26.8s	remaining: 14.4s
# 390:	learn: 0.0398370	total: 26.9s	remaining: 14.4s
# 391:	learn: 0.0397288	total: 27s	remaining: 14.3s
# 392:	learn: 0.0396674	total: 27s	remaining: 14.2s
# 393:	learn: 0.0395838	total: 27.1s	remaining: 14.2s
# 394:	learn: 0.0394786	total: 27.2s	remaining: 14.1s
# 395:	learn: 0.0393331	total: 27.3s	remaining: 14s
# 396:	learn: 0.0392034	total: 27.3s	remaining: 14s
# 397:	learn: 0.0391484	total: 27.4s	remaining: 13.9s
# 398:	learn: 0.0390592	total: 27.5s	remaining: 13.8s
# 399:	learn: 0.0389757	total: 27.5s	remaining: 13.8s
# 400:	learn: 0.0388365	total: 27.6s	remaining: 13.7s
# 401:	learn: 0.0388171	total: 27.7s	remaining: 13.6s
# 402:	learn: 0.0387340	total: 27.7s	remaining: 13.6s
# 403:	learn: 0.0386801	total: 27.8s	remaining: 13.5s
# 404:	learn: 0.0386128	total: 27.9s	remaining: 13.4s
# 405:	learn: 0.0385492	total: 27.9s	remaining: 13.4s
# 406:	learn: 0.0384163	total: 28s	remaining: 13.3s
# 407:	learn: 0.0383393	total: 28.1s	remaining: 13.2s
# 408:	learn: 0.0382832	total: 28.2s	remaining: 13.1s
# 409:	learn: 0.0382651	total: 28.2s	remaining: 13.1s
# 410:	learn: 0.0382122	total: 28.3s	remaining: 13s
# 411:	learn: 0.0381363	total: 28.3s	remaining: 12.9s
# 412:	learn: 0.0380823	total: 28.4s	remaining: 12.9s
# 413:	learn: 0.0380207	total: 28.5s	remaining: 12.8s
# 414:	learn: 0.0379889	total: 28.5s	remaining: 12.7s
# 415:	learn: 0.0379594	total: 28.6s	remaining: 12.7s
# 416:	learn: 0.0378825	total: 28.7s	remaining: 12.6s
# 417:	learn: 0.0378631	total: 28.7s	remaining: 12.5s
# 418:	learn: 0.0378018	total: 28.8s	remaining: 12.4s
# 419:	learn: 0.0377453	total: 28.9s	remaining: 12.4s
# 420:	learn: 0.0376717	total: 28.9s	remaining: 12.3s
# 421:	learn: 0.0376543	total: 29s	remaining: 12.2s
# 422:	learn: 0.0376471	total: 29.1s	remaining: 12.2s
# 423:	learn: 0.0375505	total: 29.1s	remaining: 12.1s
# 424:	learn: 0.0375196	total: 29.2s	remaining: 12s
# 425:	learn: 0.0374699	total: 29.3s	remaining: 12s
# 426:	learn: 0.0374370	total: 29.3s	remaining: 11.9s
# 427:	learn: 0.0373398	total: 29.4s	remaining: 11.8s
# 428:	learn: 0.0373204	total: 29.5s	remaining: 11.7s
# 429:	learn: 0.0372332	total: 29.5s	remaining: 11.7s
# 430:	learn: 0.0372063	total: 29.6s	remaining: 11.6s
# 431:	learn: 0.0371381	total: 29.7s	remaining: 11.5s
# 432:	learn: 0.0370770	total: 29.7s	remaining: 11.5s
# 433:	learn: 0.0370475	total: 29.8s	remaining: 11.4s
# 434:	learn: 0.0370241	total: 29.8s	remaining: 11.3s
# 435:	learn: 0.0369804	total: 29.9s	remaining: 11.3s
# 436:	learn: 0.0368820	total: 30s	remaining: 11.2s
# 437:	learn: 0.0368136	total: 30.1s	remaining: 11.1s
# 438:	learn: 0.0367706	total: 30.1s	remaining: 11s
# 439:	learn: 0.0367615	total: 30.2s	remaining: 11s
# 440:	learn: 0.0367567	total: 30.2s	remaining: 10.9s
# 441:	learn: 0.0367014	total: 30.3s	remaining: 10.8s
# 442:	learn: 0.0365921	total: 30.4s	remaining: 10.8s
# 443:	learn: 0.0365668	total: 30.4s	remaining: 10.7s
# 444:	learn: 0.0365216	total: 30.5s	remaining: 10.6s
# 445:	learn: 0.0365139	total: 30.6s	remaining: 10.6s
# 446:	learn: 0.0365034	total: 30.6s	remaining: 10.5s
# 447:	learn: 0.0364773	total: 30.7s	remaining: 10.4s
# 448:	learn: 0.0364519	total: 30.8s	remaining: 10.3s
# 449:	learn: 0.0363849	total: 30.8s	remaining: 10.3s
# 450:	learn: 0.0363639	total: 30.9s	remaining: 10.2s
# 451:	learn: 0.0363367	total: 30.9s	remaining: 10.1s
# 452:	learn: 0.0361822	total: 31s	remaining: 10.1s
# 453:	learn: 0.0361567	total: 31.1s	remaining: 10s
# 454:	learn: 0.0361388	total: 31.1s	remaining: 9.93s
# 455:	learn: 0.0360412	total: 31.2s	remaining: 9.86s
# 456:	learn: 0.0359787	total: 31.3s	remaining: 9.79s
# 457:	learn: 0.0359427	total: 31.4s	remaining: 9.72s
# 458:	learn: 0.0359308	total: 31.4s	remaining: 9.65s
# 459:	learn: 0.0359130	total: 31.5s	remaining: 9.58s
# 460:	learn: 0.0358630	total: 31.5s	remaining: 9.51s
# 461:	learn: 0.0357690	total: 31.6s	remaining: 9.45s
# 462:	learn: 0.0357643	total: 31.7s	remaining: 9.38s
# 463:	learn: 0.0357234	total: 31.8s	remaining: 9.31s
# 464:	learn: 0.0356737	total: 31.8s	remaining: 9.24s
# 465:	learn: 0.0355929	total: 31.9s	remaining: 9.17s
# 466:	learn: 0.0355365	total: 32s	remaining: 9.1s
# 467:	learn: 0.0354978	total: 32s	remaining: 9.03s
# 468:	learn: 0.0354629	total: 32.1s	remaining: 8.96s
# 469:	learn: 0.0354245	total: 32.1s	remaining: 8.89s
# 470:	learn: 0.0353202	total: 32.2s	remaining: 8.82s
# 471:	learn: 0.0352521	total: 32.3s	remaining: 8.75s
# 472:	learn: 0.0352094	total: 32.4s	remaining: 8.69s
# 473:	learn: 0.0351381	total: 32.4s	remaining: 8.62s
# 474:	learn: 0.0350697	total: 32.5s	remaining: 8.55s
# 475:	learn: 0.0350427	total: 32.6s	remaining: 8.48s
# 476:	learn: 0.0350292	total: 32.6s	remaining: 8.41s
# 477:	learn: 0.0349832	total: 32.7s	remaining: 8.34s
# 478:	learn: 0.0349633	total: 32.8s	remaining: 8.27s
# 479:	learn: 0.0348991	total: 32.8s	remaining: 8.2s
# 480:	learn: 0.0348286	total: 32.9s	remaining: 8.14s
# 481:	learn: 0.0348087	total: 33s	remaining: 8.07s
# 482:	learn: 0.0347837	total: 33s	remaining: 8s
# 483:	learn: 0.0347525	total: 33.1s	remaining: 7.93s
# 484:	learn: 0.0347216	total: 33.1s	remaining: 7.86s
# 485:	learn: 0.0347064	total: 33.2s	remaining: 7.79s
# 486:	learn: 0.0346471	total: 33.3s	remaining: 7.72s
# 487:	learn: 0.0345801	total: 33.3s	remaining: 7.65s
# 488:	learn: 0.0345488	total: 33.4s	remaining: 7.58s
# 489:	learn: 0.0344692	total: 33.5s	remaining: 7.51s
# 490:	learn: 0.0344468	total: 33.5s	remaining: 7.45s
# 491:	learn: 0.0343427	total: 33.6s	remaining: 7.38s
# 492:	learn: 0.0342765	total: 33.7s	remaining: 7.31s
# 493:	learn: 0.0342498	total: 33.7s	remaining: 7.24s
# 494:	learn: 0.0341986	total: 33.8s	remaining: 7.17s
# 495:	learn: 0.0341769	total: 33.9s	remaining: 7.1s
# 496:	learn: 0.0341373	total: 33.9s	remaining: 7.04s
# 497:	learn: 0.0341112	total: 34s	remaining: 6.96s
# 498:	learn: 0.0340680	total: 34.1s	remaining: 6.9s
# 499:	learn: 0.0340547	total: 34.1s	remaining: 6.83s
# 500:	learn: 0.0340238	total: 34.2s	remaining: 6.76s
# 501:	learn: 0.0340197	total: 34.3s	remaining: 6.69s
# 502:	learn: 0.0339822	total: 34.3s	remaining: 6.62s
# 503:	learn: 0.0339260	total: 34.4s	remaining: 6.55s
# 504:	learn: 0.0338372	total: 34.5s	remaining: 6.48s
# 505:	learn: 0.0338072	total: 34.5s	remaining: 6.41s
# 506:	learn: 0.0337197	total: 34.6s	remaining: 6.35s
# 507:	learn: 0.0336929	total: 34.7s	remaining: 6.28s
# 508:	learn: 0.0336547	total: 34.7s	remaining: 6.21s
# 509:	learn: 0.0336337	total: 34.8s	remaining: 6.14s
# 510:	learn: 0.0336046	total: 34.9s	remaining: 6.07s
# 511:	learn: 0.0335647	total: 34.9s	remaining: 6s
# 512:	learn: 0.0335152	total: 35s	remaining: 5.93s
# 513:	learn: 0.0334549	total: 35.1s	remaining: 5.87s
# 514:	learn: 0.0333969	total: 35.1s	remaining: 5.8s
# 515:	learn: 0.0333421	total: 35.2s	remaining: 5.73s
# 516:	learn: 0.0332521	total: 35.3s	remaining: 5.66s
# 517:	learn: 0.0331550	total: 35.3s	remaining: 5.59s
# 518:	learn: 0.0330708	total: 35.4s	remaining: 5.53s
# 519:	learn: 0.0330288	total: 35.5s	remaining: 5.46s
# 520:	learn: 0.0330086	total: 35.5s	remaining: 5.39s
# 521:	learn: 0.0329973	total: 35.6s	remaining: 5.32s
# 522:	learn: 0.0329153	total: 35.7s	remaining: 5.25s
# 523:	learn: 0.0328885	total: 35.7s	remaining: 5.18s
# 524:	learn: 0.0328285	total: 35.8s	remaining: 5.11s
# 525:	learn: 0.0328179	total: 35.9s	remaining: 5.04s
# 526:	learn: 0.0328019	total: 35.9s	remaining: 4.98s
# 527:	learn: 0.0327330	total: 36s	remaining: 4.91s
# 528:	learn: 0.0326946	total: 36.1s	remaining: 4.84s
# 529:	learn: 0.0326319	total: 36.1s	remaining: 4.77s
# 530:	learn: 0.0325589	total: 36.2s	remaining: 4.7s
# 531:	learn: 0.0325522	total: 36.3s	remaining: 4.63s
# 532:	learn: 0.0324822	total: 36.3s	remaining: 4.57s
# 533:	learn: 0.0324313	total: 36.4s	remaining: 4.5s
# 534:	learn: 0.0323751	total: 36.5s	remaining: 4.43s
# 535:	learn: 0.0322799	total: 36.5s	remaining: 4.36s
# 536:	learn: 0.0322718	total: 36.6s	remaining: 4.29s
# 537:	learn: 0.0322188	total: 36.7s	remaining: 4.22s
# 538:	learn: 0.0322005	total: 36.7s	remaining: 4.16s
# 539:	learn: 0.0321684	total: 36.8s	remaining: 4.09s
# 540:	learn: 0.0321487	total: 36.8s	remaining: 4.02s
# 541:	learn: 0.0321170	total: 36.9s	remaining: 3.95s
# 542:	learn: 0.0321110	total: 37s	remaining: 3.88s
# 543:	learn: 0.0320834	total: 37s	remaining: 3.81s
# 544:	learn: 0.0320608	total: 37.1s	remaining: 3.74s
# 545:	learn: 0.0320361	total: 37.2s	remaining: 3.67s
# 546:	learn: 0.0319933	total: 37.2s	remaining: 3.61s
# 547:	learn: 0.0319719	total: 37.3s	remaining: 3.54s
# 548:	learn: 0.0319394	total: 37.4s	remaining: 3.47s
# 549:	learn: 0.0318797	total: 37.4s	remaining: 3.4s
# 550:	learn: 0.0318407	total: 37.5s	remaining: 3.33s
# 551:	learn: 0.0318284	total: 37.6s	remaining: 3.27s
# 552:	learn: 0.0317900	total: 37.6s	remaining: 3.2s
# 553:	learn: 0.0317527	total: 37.7s	remaining: 3.13s
# 554:	learn: 0.0317252	total: 37.8s	remaining: 3.06s
# 555:	learn: 0.0316876	total: 37.8s	remaining: 2.99s
# 556:	learn: 0.0316294	total: 37.9s	remaining: 2.92s
# 557:	learn: 0.0315669	total: 38s	remaining: 2.86s
# 558:	learn: 0.0315246	total: 38s	remaining: 2.79s
# 559:	learn: 0.0314746	total: 38.1s	remaining: 2.72s
# 560:	learn: 0.0314357	total: 38.2s	remaining: 2.65s
# 561:	learn: 0.0314106	total: 38.2s	remaining: 2.58s
# 562:	learn: 0.0313671	total: 38.3s	remaining: 2.52s
# 563:	learn: 0.0313629	total: 38.4s	remaining: 2.45s
# 564:	learn: 0.0313152	total: 38.4s	remaining: 2.38s
# 565:	learn: 0.0312735	total: 38.5s	remaining: 2.31s
# 566:	learn: 0.0312285	total: 38.6s	remaining: 2.24s
# 567:	learn: 0.0312000	total: 38.6s	remaining: 2.17s
# 568:	learn: 0.0311177	total: 38.7s	remaining: 2.11s
# 569:	learn: 0.0310042	total: 38.8s	remaining: 2.04s
# 570:	learn: 0.0308948	total: 38.8s	remaining: 1.97s
# 571:	learn: 0.0308245	total: 38.9s	remaining: 1.91s
# 572:	learn: 0.0307844	total: 39s	remaining: 1.84s
# 573:	learn: 0.0307137	total: 39.1s	remaining: 1.77s
# 574:	learn: 0.0306688	total: 39.1s	remaining: 1.7s
# 575:	learn: 0.0306492	total: 39.2s	remaining: 1.63s
# 576:	learn: 0.0306362	total: 39.2s	remaining: 1.56s
# 577:	learn: 0.0305847	total: 39.3s	remaining: 1.5s
# 578:	learn: 0.0305714	total: 39.4s	remaining: 1.43s
# 579:	learn: 0.0305422	total: 39.4s	remaining: 1.36s
# 580:	learn: 0.0305249	total: 39.5s	remaining: 1.29s
# 581:	learn: 0.0304946	total: 39.6s	remaining: 1.22s
# 582:	learn: 0.0304552	total: 39.6s	remaining: 1.16s
# 583:	learn: 0.0304442	total: 39.7s	remaining: 1.09s
# 584:	learn: 0.0303149	total: 39.8s	remaining: 1.02s
# 585:	learn: 0.0302679	total: 39.8s	remaining: 952ms
# 586:	learn: 0.0302275	total: 39.9s	remaining: 884ms
# 587:	learn: 0.0302111	total: 40s	remaining: 816ms
# 588:	learn: 0.0300562	total: 40s	remaining: 748ms
# 589:	learn: 0.0300285	total: 40.1s	remaining: 680ms
# 590:	learn: 0.0299729	total: 40.2s	remaining: 612ms
# 591:	learn: 0.0299677	total: 40.2s	remaining: 544ms
# 592:	learn: 0.0299640	total: 40.3s	remaining: 476ms
# 593:	learn: 0.0298916	total: 40.4s	remaining: 408ms
# 594:	learn: 0.0298701	total: 40.4s	remaining: 340ms
# 595:	learn: 0.0298456	total: 40.5s	remaining: 272ms
# 596:	learn: 0.0297958	total: 40.6s	remaining: 204ms
# 597:	learn: 0.0297132	total: 40.6s	remaining: 136ms
# 598:	learn: 0.0296498	total: 40.7s	remaining: 68ms
# 599:	learn: 0.0296230	total: 40.8s	remaining: 0us
# 第  5  折交叉验证 :  accuracy ：  0.9817857142857143
# ==============================RandomForestClassifier==============================
# 第  1  折交叉验证开始...
# 第  1  折交叉验证 :  accuracy ：  0.961
# 第  2  折交叉验证开始...
# 第  2  折交叉验证 :  accuracy ：  0.9625
# 第  3  折交叉验证开始...
# 第  3  折交叉验证 :  accuracy ：  0.9648571428571429
# 第  4  折交叉验证开始...
# 第  4  折交叉验证 :  accuracy ：  0.9626428571428571
# 第  5  折交叉验证开始...
# 第  5  折交叉验证 :  accuracy ：  0.9618571428571429

# %%
y_submission
# Out:
# array([0, 2, 2, ..., 2, 0, 0])

# %%
np.eye(4)[y_submission].shape
# Out:
# (20000, 4)

# %%
df = pd.read_csv('sample_submit.csv')

df[['label_0', 'label_1', 'label_2', 'label_3']] = np.eye(4)[y_submission]

df.to_csv('submission_prob.csv', index=False)
